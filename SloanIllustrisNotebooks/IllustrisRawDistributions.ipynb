# %% [markdown]
# # Galaxy property distributions for all galaxies in the GZ Illustris dataset

# %% [markdown]
# ## Module Imports

# %%
import SciServer.CasJobs as CasJobs # query with CasJobs
import SciServer.SciDrive           # read/write to/from SciDrive
import SciServer.LoginPortal

# %%
from pymongo import MongoClient
from bson.son import SON
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import astropy.io.fits as astrofits
from astropy.table import Table
import scipy
from scipy import interpolate
import pickle
import skimage.io 
import urllib3
import io
import requests
# %matplotlib inline

# %% [markdown]
# ## Initial Setup

# %% [markdown]
# ### Control output verbosity and enable foratted prinding of data structures

# %%
verbose = True
if verbose :
    import pprint
    from IPython.core.display import display
    prettyPrinter = pprint.PrettyPrinter(indent=4)

# %% [markdown]
# ### Credentials and static variables for Illustris Web Service
# This API key should not require updating.

# %%
illustrisAPIKey="44ddc0a0574472a27514600007f1a6a1"
illustrisBaseUrl = 'http://www.illustris-project.org/api/'
illustrisHeaders = {"api-key":illustrisAPIKey}

# %% [markdown]
# ### Utility function for performing queries of the Illustris web service

# %%
def illustrisGet(path, params = None, headers = None):
    # make HTTP GET request to path
    r = requests.get(path, params=params, headers=headers)
    
    # raise exception if response code is not HTTP SUCCESS (200)
    r.raise_for_status()
    
    if r.headers['content-type'] == 'application/json':
        return r.json() # parse json responses automatically
    return r

# %% [markdown]
# ### Credentials for SDSS CasJobs/SciServer interface
# This key must be updated every time that the SciServer logout/login cycle occurs.

# %%
sciServerAuthToken = 'b957682299f9427e93c9a55355e85e6e'
SciServer.LoginPortal.setKeystoneToken(sciServerAuthToken)
userManager = SciServer.LoginPortal.getKeystoneUserWithToken(sciServerAuthToken)

# %% [markdown]
# ### Variables pertaining to local  `mongodb` Galaxy Zoo classifications database

# %%
clientInstance = MongoClient()
database = clientInstance['test']
gzClassifications = database['galaxy_zoo_classifications']
gzSubjects = database['galaxy_zoo_subjects']
gzGroups = database['galaxy_zoo_groups']

# %% [markdown]
# ### Variables that control serialization and loading of data extracted from the GZ mongo database

# %%
saveFullIllustrisMongoDataFrame = False
fullIllustrisMongoDataFramePath = '/Users/hughdickinson/Documents/Development/Sloan-Illustris-Comparison/data/FullIllustrisMongoDataFrame.pkl'

# %% [markdown]
# ### Variables that control serialization and loading of data downloaded from the Illustris Web Service

# %%
saveFullIllustrisWebServiceDataFrame = False
fullIllustrisWebServiceDataFramePath = '/Users/hughdickinson/Documents/Development/Sloan-Illustris-Comparison/data/FullIllustrisWebServiceDataFrame.pkl'

# %% [markdown]
# ### Variables that control serialization and loading of GZ-related data downloaded from the SDSS SkyServer

# %%
saveGalaxyZooSDSSDataFrame = False
galaxyZooSDSSDataFramePath = '/Users/hughdickinson/Documents/Development/Sloan-Illustris-Comparison/data/GalaxyZooSDSSDataFrame.pkl'

# %% [markdown]
# ## Query `mongodb` database to retrieve subjects for the *illustris* survey

# %%
fullIllustrisMongoDataFrame = None

if saveFullIllustrisMongoDataFrame:
    fullIllustrisMongoData = list(gzSubjects.find({"metadata.survey": "illustris"}, 
                                                     {"metadata": 1, "state" : 1, "location": 1}))
    
    fullIllustrisMongoDataFrame = pd.DataFrame([ (
                fullIllustrisMongoDatum["metadata"]["subhalo_id"],
                fullIllustrisMongoDatum["metadata"]["priority"],
                fullIllustrisMongoDatum["state"],
                fullIllustrisMongoDatum["location"]["standard"],
                fullIllustrisMongoDatum["location"],
                fullIllustrisMongoDatum["metadata"]
            ) for fullIllustrisMongoDatum in fullIllustrisMongoData],
                                               columns=["subhalo_id",
                                                        "priority",
                                                        "state", 
                                                        "standard_location",
                                                        "all_location_data",
                                                        "all_metadata"]
                                              )
        
    fullIllustrisMongoDataFrame.to_pickle(fullIllustrisMongoDataFramePath)
else :
    pickleDataFile = open(fullIllustrisMongoDataFramePath, mode='rb')
    fullIllustrisMongoDataFrame = pickle.load(pickleDataFile) 
    pickleDataFile.close()
    
if verbose :
    display (fullIllustrisMongoDataFrame)
# Out:
#         subhalo_id     priority     state  \
# 0               25   fixed_view  complete
# 1               26   fixed_view  complete
# 2               27   fixed_view  complete
# 3               28   fixed_view  complete
# 4               29   fixed_view  complete
# 5               40   fixed_view  complete
# 6               45   fixed_view  complete
# 7               46   fixed_view  complete
# 8               47   fixed_view  complete
# 9               48   fixed_view  complete
# 10              49   fixed_view  complete
# 11              41   fixed_view  complete
# 12               0   fixed_view  complete
# 13               1   fixed_view  complete
# 14              10   fixed_view  complete
# 15             101   fixed_view  complete
# 16             102   fixed_view  complete
# 17               3   fixed_mass  complete
# 18              30   fixed_view  complete
# 19              31   fixed_view  complete
# 20              32   fixed_view  complete
# 21              33   fixed_view  complete
# 22              34   fixed_view  complete
# 23              35   fixed_view  complete
# 24              36   fixed_view  complete
# 25              37   fixed_view  complete
# 26              38   fixed_view  complete
# 27              39   fixed_view  complete
# 28               4   fixed_mass  complete
# 29              42   fixed_view  complete
# ...            ...          ...       ...
# 110226      519479  full_sample    paused
# 110227      518759  full_sample    paused
# 110228      519747  full_sample    paused
# 110229      520188  full_sample    paused
# 110230      520742  full_sample    paused
# 110231      520784  full_sample    paused
# 110232      521420  full_sample    paused
# 110233      521231  full_sample    paused
# 110234      521913  full_sample    paused
# 110235      521442  full_sample    paused
# 110236      521931  full_sample    paused
# 110237      522517  full_sample    paused
# 110238      523126  full_sample    paused
# 110239      524084  full_sample    paused
# 110240      524223  full_sample    paused
# 110241      524679  full_sample    paused
# 110242      524364  full_sample    paused
# 110243      525000  full_sample    paused
# 110244      525174  full_sample    paused
# 110245      525710  full_sample    paused
# 110246      526410  full_sample    paused
# 110247      526649  full_sample    paused
# 110248      527538  full_sample    paused
# 110249      529353  full_sample    paused
# 110250      530404  full_sample    paused
# 110251      530529  full_sample    paused
# 110252      538541  full_sample    paused
# 110253      525516   fixed_mass  complete
# 110254      527544  full_sample    paused
# 110255      543284  full_sample    paused
#
#                                         standard_location  \
# 0       http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 1       http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 2       http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 3       http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 4       http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 5       http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 6       http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 7       http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 8       http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 9       http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 10      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 11      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 12      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 13      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 14      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 15      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 16      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 17      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 18      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 19      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 20      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 21      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 22      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 23      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 24      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 25      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 26      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 27      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 28      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 29      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# ...                                                   ...
# 110226  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110227  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110228  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110229  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110230  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110231  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110232  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110233  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110234  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110235  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110236  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110237  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110238  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110239  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110240  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110241  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110242  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110243  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110244  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110245  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110246  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110247  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110248  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110249  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110250  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110251  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110252  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110253  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110254  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110255  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
#
#                                         all_location_data  \
# 0       {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 1       {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 2       {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 3       {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 4       {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 5       {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 6       {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 7       {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 8       {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 9       {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 10      {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 11      {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 12      {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 13      {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 14      {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 15      {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 16      {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 17      {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 18      {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 19      {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 20      {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 21      {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 22      {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 23      {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 24      {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 25      {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 26      {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 27      {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 28      {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 29      {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# ...                                                   ...
# 110226  {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 110227  {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 110228  {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 110229  {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 110230  {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 110231  {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 110232  {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 110233  {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 110234  {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 110235  {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 110236  {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 110237  {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 110238  {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 110239  {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 110240  {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 110241  {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 110242  {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 110243  {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 110244  {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 110245  {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 110246  {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 110247  {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 110248  {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 110249  {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 110250  {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 110251  {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 110252  {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 110253  {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 110254  {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
# 110255  {'inverted': 'http://www.galaxyzoo.org.s3.amaz...
#
#                                              all_metadata
# 0       {'survey': 'illustris', 'background': 0, 'subh...
# 1       {'survey': 'illustris', 'background': 0, 'subh...
# 2       {'survey': 'illustris', 'background': 0, 'subh...
# 3       {'survey': 'illustris', 'background': 0, 'subh...
# 4       {'survey': 'illustris', 'background': 0, 'subh...
# 5       {'survey': 'illustris', 'background': 0, 'subh...
# 6       {'survey': 'illustris', 'background': 0, 'subh...
# 7       {'survey': 'illustris', 'background': 0, 'subh...
# 8       {'survey': 'illustris', 'background': 0, 'subh...
# 9       {'survey': 'illustris', 'background': 0, 'subh...
# 10      {'survey': 'illustris', 'background': 0, 'subh...
# 11      {'survey': 'illustris', 'background': 0, 'subh...
# 12      {'survey': 'illustris', 'background': 0, 'subh...
# 13      {'survey': 'illustris', 'background': 0, 'subh...
# 14      {'survey': 'illustris', 'background': 0, 'subh...
# 15      {'survey': 'illustris', 'background': 0, 'subh...
# 16      {'survey': 'illustris', 'background': 0, 'subh...
# 17      {'survey': 'illustris', 'background': 0, 'subh...
# 18      {'survey': 'illustris', 'background': 0, 'subh...
# 19      {'survey': 'illustris', 'background': 0, 'subh...
# 20      {'survey': 'illustris', 'background': 0, 'subh...
# 21      {'survey': 'illustris', 'background': 0, 'subh...
# 22      {'survey': 'illustris', 'background': 0, 'subh...
# 23      {'survey': 'illustris', 'background': 0, 'subh...
# 24      {'survey': 'illustris', 'background': 0, 'subh...
# 25      {'survey': 'illustris', 'background': 0, 'subh...
# 26      {'survey': 'illustris', 'background': 0, 'subh...
# 27      {'survey': 'illustris', 'background': 0, 'subh...
# 28      {'survey': 'illustris', 'background': 0, 'subh...
# 29      {'survey': 'illustris', 'background': 0, 'subh...
# ...                                                   ...
# 110226  {'survey': 'illustris', 'background': 3, 'subh...
# 110227  {'survey': 'illustris', 'background': 3, 'subh...
# 110228  {'survey': 'illustris', 'background': 3, 'subh...
# 110229  {'survey': 'illustris', 'background': 3, 'subh...
# 110230  {'survey': 'illustris', 'background': 3, 'subh...
# 110231  {'survey': 'illustris', 'background': 3, 'subh...
# 110232  {'survey': 'illustris', 'background': 3, 'subh...
# 110233  {'survey': 'illustris', 'background': 3, 'subh...
# 110234  {'survey': 'illustris', 'background': 3, 'subh...
# 110235  {'survey': 'illustris', 'background': 3, 'subh...
# 110236  {'survey': 'illustris', 'background': 3, 'subh...
# 110237  {'survey': 'illustris', 'background': 3, 'subh...
# 110238  {'survey': 'illustris', 'background': 3, 'subh...
# 110239  {'survey': 'illustris', 'background': 3, 'subh...
# 110240  {'survey': 'illustris', 'background': 3, 'subh...
# 110241  {'survey': 'illustris', 'background': 3, 'subh...
# 110242  {'survey': 'illustris', 'background': 3, 'subh...
# 110243  {'survey': 'illustris', 'background': 3, 'subh...
# 110244  {'survey': 'illustris', 'background': 3, 'subh...
# 110245  {'survey': 'illustris', 'background': 3, 'subh...
# 110246  {'survey': 'illustris', 'background': 3, 'subh...
# 110247  {'survey': 'illustris', 'background': 3, 'subh...
# 110248  {'survey': 'illustris', 'background': 3, 'subh...
# 110249  {'survey': 'illustris', 'background': 3, 'subh...
# 110250  {'survey': 'illustris', 'background': 3, 'subh...
# 110251  {'survey': 'illustris', 'background': 3, 'subh...
# 110252  {'survey': 'illustris', 'background': 3, 'subh...
# 110253  {'survey': 'illustris', 'background': 3, 'subh...
# 110254  {'survey': 'illustris', 'background': 3, 'subh...
# 110255  {'survey': 'illustris', 'background': 3, 'subh...
#
# [110256 rows x 6 columns]

# %% [markdown]
# ## Retrieve data for all *unique* database-retrieved subhalo IDs from the Illustris Web Service

# %%
fullIllustrisWebServiceDataFrame = None

if saveFullIllustrisWebServiceDataFrame :
    
    fullIllustrisWebServiceData = []
    
    illustris1SimulationUrl = [ entry['url'] for entry in illustrisGet(illustrisBaseUrl, headers=illustrisHeaders)['simulations'] if entry['name'] == 'Illustris-1'][0]
    illustris1SnapshotsUrl = illustrisGet(illustris1SimulationUrl, headers=illustrisHeaders)['snapshots']
    illustris1ZeroRedshiftSnapshotUrl = illustrisGet(illustris1SnapshotsUrl, headers=illustrisHeaders)[-1]['url']
    illustris1ZeroRedshiftSubHalosUrl = illustrisGet(illustris1ZeroRedshiftSnapshotUrl, headers=illustrisHeaders)['subhalos']

    if verbose :
        print('Base URL for Illustris-1 Simulation => {}'.format(illustris1SimulationUrl))
        print('Base URL for Illustris-1 Simulation Snapshots => {}'.format(illustris1SnapshotsUrl))
        print('Base URL for Illustris-1 Simulation Zero Redshift Snapshot => {}'.format(illustris1ZeroRedshiftSnapshotUrl))
        print('Base URL for Illustris-1 Simulation Zero Redshift Halos => {}\n'.format(illustris1ZeroRedshiftSubHalosUrl))

    requiredIllustrisHaloIds = fullIllustrisMongoDataFrame.groupby('subhalo_id').first().index.values
    
    for requiredIllustrisHaloIndex, requiredIllustrisHaloId in enumerate(requiredIllustrisHaloIds) :
        illustris1ZeroRedshiftSubHaloUrl = illustris1ZeroRedshiftSubHalosUrl + str(requiredIllustrisHaloId)
        fullIllustrisWebServiceData.append(illustrisGet(illustris1ZeroRedshiftSubHaloUrl, headers=illustrisHeaders))
        if requiredIllustrisHaloIndex % 100 == 0 :
            print ('Retrieved data for {} of {} halos...'.format(requiredIllustrisHaloIndex, len(requiredIllustrisHaloIds)))
    print ('Retrieved data for {} halos. Done.'.format(requiredIllustrisHaloIndex))
    
    fullIllustrisWebServiceDataFrame = pd.DataFrame(fullIllustrisWebServiceData)

    fullIllustrisWebServiceDataFrame.to_pickle(fullIllustrisWebServiceDataFramePath)
else :
    pickleDataFile = open(fullIllustrisWebServiceDataFramePath, mode='rb')
    fullIllustrisWebServiceDataFrame = pickle.load(pickleDataFile) 
    pickleDataFile.close()  

if verbose :
    display (fullIllustrisWebServiceDataFrame)
# Out:
# Base URL for Illustris-1 Simulation => http://www.illustris-project.org/api/Illustris-1/
# Base URL for Illustris-1 Simulation Snapshots => http://www.illustris-project.org/api/Illustris-1/snapshots/
# Base URL for Illustris-1 Simulation Zero Redshift Snapshot => http://www.illustris-project.org/api/Illustris-1/snapshots/135/
# Base URL for Illustris-1 Simulation Zero Redshift Halos => http://www.illustris-project.org/api/Illustris-1/snapshots/135/subhalos/
# Retrieved data for 0 halos...
# Retrieved data for 100 halos...
# Retrieved data for 200 halos...
# Retrieved data for 300 halos...
# Retrieved data for 400 halos...
# Retrieved data for 500 halos...
# Retrieved data for 600 halos...
# Retrieved data for 700 halos...
# Retrieved data for 800 halos...
# Retrieved data for 900 halos...
# Retrieved data for 1000 halos...
# Retrieved data for 1100 halos...
# Retrieved data for 1200 halos...
# Retrieved data for 1300 halos...
# Retrieved data for 1400 halos...
# Retrieved data for 1500 halos...
# Retrieved data for 1600 halos...
# Retrieved data for 1700 halos...
# Retrieved data for 1800 halos...
# Retrieved data for 1900 halos...
# Retrieved data for 2000 halos...
# Retrieved data for 2100 halos...
# Retrieved data for 2200 halos...
# Retrieved data for 2300 halos...
# Retrieved data for 2400 halos...
# Retrieved data for 2500 halos...
# Retrieved data for 2600 halos...
# Retrieved data for 2700 halos...
# Retrieved data for 2800 halos...
# Retrieved data for 2900 halos...
# Retrieved data for 3000 halos...
# Retrieved data for 3100 halos...
# Retrieved data for 3200 halos...
# Retrieved data for 3300 halos...
# Retrieved data for 3400 halos...
# Retrieved data for 3500 halos...
# Retrieved data for 3600 halos...
# Retrieved data for 3700 halos...
# Retrieved data for 3800 halos...
# Retrieved data for 3900 halos...
# Retrieved data for 4000 halos...
# Retrieved data for 4100 halos...
# Retrieved data for 4200 halos...
# Retrieved data for 4300 halos...
# Retrieved data for 4400 halos...
# Retrieved data for 4500 halos...
# Retrieved data for 4600 halos...
# Retrieved data for 4700 halos...
# Retrieved data for 4800 halos...
# Retrieved data for 4900 halos...
# Retrieved data for 5000 halos...
# Retrieved data for 5100 halos...
# Retrieved data for 5200 halos...
# Retrieved data for 5300 halos...
# Retrieved data for 5400 halos...
# Retrieved data for 5500 halos...
# Retrieved data for 5600 halos...
# Retrieved data for 5700 halos...
# Retrieved data for 5800 halos...
# Retrieved data for 5900 halos...
# Retrieved data for 6000 halos...
# Retrieved data for 6100 halos...
# Retrieved data for 6200 halos...
# Retrieved data for 6300 halos...
# Retrieved data for 6400 halos...
# Retrieved data for 6500 halos...
# Retrieved data for 6600 halos...
# Retrieved data for 6700 halos...
# Retrieved data for 6800 halos...
# Retrieved data for 6890 halos. Done.
#             bhmdot       cm_x      cm_y     cm_z  \
# 0     3.244590e-04    887.726  26311.20  18092.8
# 1     1.260800e-06    184.273  24579.40  16865.0
# 2     4.166120e-04    765.316  26758.30  17215.4
# 3     9.907680e-03   1204.510  26492.10  18221.3
# 4     8.635300e-06    994.455  26623.40  17597.5
# 5     8.833150e-03   1120.970  26604.80  18433.7
# 6     3.000000e-10    809.180  26290.80  18199.2
# 7     2.145650e-03   1425.950  26676.90  17298.5
{'parent_halo': 'http://www.illustris-project....         -1         -1
# 19    {'parent_halo': 'http://www.illustris-project....         -1         -1
# 20    {'parent_halo': 'http://www.illustris-project....         -1         -1
# 21    {'parent_halo': 'http://www.illustris-project....         -1         -1
# 22    {'parent_halo': 'http://www.illustris-project....         -1         -1
# 23    {'parent_halo': 'http://www.illustris-project....         -1         -1
# 24    {'parent_halo': 'http://www.illustris-project....         -1         -1
# 25    {'parent_halo': 'http://www.illustris-project....         -1         -1
# 26    {'parent_halo': 'http://www.illustris-project....         -1         -1
# 27    {'parent_halo': 'http://www.illustris-project....         -1         -1
# 28    {'parent_halo': 'http://www.illustris-project....         -1         -1
# 29    {'parent_halo': 'http://www.illustris-project....         -1         -1
# ...                                                 ...        ...        ...
# 6861  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6862  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6863  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6864  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6865  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6866  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6867  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6868  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6869  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6870  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6871  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6872  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6873  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6874  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6875  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6876  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6877  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6878  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6879  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6880  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6881  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6882  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6883  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6884  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6885  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6886  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6887  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6888  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6889  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6890  {'parent_halo': 'http://www.illustris-project....         -1         -1
#
#       gasmetallicity  gasmetallicityhalfrad  gasmetallicitymaxrad    ...     \
# 0           0.009294               0.011018              0.007500    ...
# 1           0.032274               0.033691              0.027029    ...
# 2           0.040203               0.041272              0.038959    ...
# 3           0.050764               0.059546              0.054003    ...
# 4           0.023837               0.025455              0.025549    ...
# 5           0.054275               0.054488              0.054275    ...
# 6           0.012316               0.012227              0.012263    ...
# 7           0.041462               0.044658              0.044915    ...
# 8           0.000000               0.000000              0.000000    ...
# 9           0.000000               0.000000              0.000000    ...
# 10          0.051617               0.059555              0.054371    ...
# 11          0.011751               0.011491              0.011525    ...
# 12          0.000000               0.000000              0.000000    ...
# 13          0.000000               0.000000              0.000000    ...
# 14          0.000000               0.000000              0.000000    ...
# 15          0.000000               0.000000              0.000000    ...
# 16          0.000000               0.000000              0.000000    ...
# 17          0.035683               0.047043              0.032874    ...
# 18          0.000000               0.000000              0.000000    ...
# 19          0.065134               0.065134              0.065134    ...
# 20          0.000000               0.000000              0.000000    ...
# 21          0.041668               0.053713              0.043222    ...
# 22          0.037506               0.044152              0.042127    ...
# 23          0.022667               0.033250              0.018437    ...
# 24          0.061614               0.065944              0.068640    ...
# 25          0.000000               0.000000              0.000000    ...
# 26          0.029495               0.044153              0.024210    ...
# 27          0.033422               0.042080              0.029753    ...
# 28          0.049945               0.058511              0.051653    ...
# 29          0.041217               0.048770              0.041170    ...
# ...              ...                    ...                   ...    ...
# 6861        0.017930               0.027662              0.018385    ...
# 6862        0.018256               0.023913              0.018925    ...
# 6863        0.024467               0.030807              0.022703    ...
# 6864        0.021793               0.031875              0.021079    ...
# 6865        0.019587               0.028367              0.018663    ...
# 6866        0.018346               0.027762              0.016230    ...
# 6867        0.017866               0.023291              0.018107    ...
# 6868        0.026410               0.031651              0.027064    ...
# 6869        0.030090               0.036594              0.031339    ...
# 6870        0.018391               0.024350              0.019265    ...
# 6871        0.028371               0.042795              0.026746    ...
# 6872        0.028463               0.035730              0.027749    ...
# 6873        0.026006               0.037954              0.019814    ...
# 6874        0.017550               0.024717              0.017191    ...
# 6875        0.025097               0.034431              0.023808    ...
# 6876        0.021252               0.028727              0.019616    ...
# 6877        0.019761               0.027732              0.017433    ...
# 6878        0.020449               0.029094              0.018878    ...
# 6879        0.020505               0.028441              0.020345    ...
# 6880        0.022954               0.032972              0.023992    ...
# 6881        0.018159               0.026653              0.018219    ...
# 6882        0.024790               0.035949              0.023823    ...
# 6883        0.021425               0.029097              0.021864    ...
# 6884        0.020195               0.028859              0.020550    ...
# 6885        0.019269               0.028406              0.017653    ...
# 6886        0.024670               0.031812              0.025762    ...
# 6887        0.033170               0.034789              0.033316    ...
# 6888        0.025316               0.032258              0.025341    ...
# 6889        0.022521               0.031176              0.024330    ...
# 6890        0.000000               0.000000              0.000000    ...
#
#       stellarphotometricsrad  \
# 0                    37.5182
# 1                    17.3275
# 2                    13.9054
# 3                    19.5589
# 4                    12.5330
# 5                    13.0157
# 6                    13.5273
# 7                    10.2957
# 8                     9.8320
# 9                    11.2121
# 10                   13.5160
# 11                    7.9947
# 12                    7.7907
# 13                   10.8659
# 14                    8.1942
# 15                   10.2811
# 16                    8.0476
# 17                    7.3050
# 18                    8.5736
# 19                    7.8475
# 20                    8.7859
# 21                    7.9675
# 22                    7.2974
# 23                    5.4734
# 24                    6.8014
# 25                    7.2687
# 26                    7.8846
# 27                    6.3877
# 28                    9.4591
# 29                    5.1580
# ...                      ...
# 6861                  4.5652
# 6862                  4.0137
# 6863                  4.8696
# 6864                  3.7662
# 6865                  4.8243
# 6866                  4.3986
# 6867                  3.8526
# 6868                  4.4483
# 6869                  4.0546
# 6870                  3.6707
# 6871                  4.4445
# 6872                  4.6555
# 6873                  4.1751
# 6874                  4.5728
# 6875                  4.7563
# 6876                  4.6579
# 6877                  4.5510
# 6878                  4.0181
# 6879                  4.2556
# 6880                  3.8961
# 6881                  3.1926
# 6882                  4.4893
# 6883                  4.4661
# 6884                  4.2077
# 6885                  4.7818
# 6886                  3.5801
# 6887                  4.0360
# 6888                  4.2359
# 6889                  3.7768
# 6890                  2.9605
#
#                                      supplementary_data  \
# 0     {'stellar_mocks': {'image_subhalo': 'http://ww...
# 1     {'stellar_mocks': {'image_subhalo': 'http://ww...
# 2     {'stellar_mocks': {'image_subhalo': 'http://ww...
# 3     {'stellar_mocks': {'image_subhalo': 'http://ww...
# 4     {'stellar_mocks': {'image_subhalo': 'http://ww...
# 5     {'stellar_mocks': {'image_subhalo': 'http://ww...
# 6     {'stellar_mocks': {'image_subhalo': 'http://ww...
# 7     {'stellar_mocks': {'image_subhalo': 'http://ww...
# 8     {'stellar_mocks': {'image_subhalo': 'http://ww...
# 9     {'stellar_mocks': {'image_subhalo': 'http://ww...
# 10    {'stellar_mocks': {'image_subhalo': 'http://ww...
# 11    {'stellar_mocks': {'image_subhalo': 'http://ww...
# 12    {'stellar_mocks': {'image_subhalo': 'http://ww...
# 13    {'stellar_mocks': {'image_subhalo': 'http://ww...
# 14    {'stellar_mocks': {'image_subhalo': 'http://ww...
# 15    {'stellar_mocks': {'image_subhalo': 'http://ww...
# 16    {'stellar_mocks': {'image_subhalo': 'http://ww...
# 17    {'stellar_mocks': {'image_subhalo': 'http://ww...
# 18    {'stellar_mocks': {'image_subhalo': 'http://ww...
# 19    {'stellar_mocks': {'image_subhalo': 'http://ww...
# 20    {'stellar_mocks': {'image_subhalo': 'http://ww...
# 21    {'stellar_mocks': {'image_subhalo': 'http://ww...
# 22    {'stellar_mocks': {'image_subhalo': 'http://ww...
# 23    {'stellar_mocks': {'image_subhalo': 'http://ww...
# 24    {'stellar_mocks': {'image_subhalo': 'http://ww...
# 25    {'stellar_mocks': {'image_subhalo': 'http://ww...
# 26    {'stellar_mocks': {'image_subhalo': 'http://ww...
# 27    {'stellar_mocks': {'image_subhalo': 'http://ww...
# 28    {'stellar_mocks': {'image_subhalo': 'http://ww...
# 29    {'stellar_mocks': {'image_subhalo': 'http://ww...
# ...                                                 ...
# 6861  {'stellar_mocks': {'image_subhalo': 'http://ww...
# 6862  {'stellar_mocks': {'image_subhalo': 'http://ww...
# 6863  {'stellar_mocks': {'image_subhalo': 'http://ww...
# 6864  {'stellar_mocks': {'image_subhalo': 'http://ww...
# 6865  {'stellar_mocks': {'image_subhalo': 'http://ww...
# 6866  {'stellar_mocks': {'image_subhalo': 'http://ww...
# 6867  {'stellar_mocks': {'image_subhalo': 'http://ww...
# 6868  {'stellar_mocks': {'image_subhalo': 'http://ww...
# 6869  {'stellar_mocks': {'image_subhalo': 'http://ww...
# 6870  {'stellar_mocks': {'image_subhalo': 'http://ww...
# 6871  {'stellar_mocks': {'image_subhalo': 'http://ww...
# 6872  {'stellar_mocks': {'image_subhalo': 'http://ww...
# 6873  {'stellar_mocks': {'image_subhalo': 'http://ww...
# 6874  {'stellar_mocks': {'image_subhalo': 'http://ww...
# 6875  {'stellar_mocks': {'image_subhalo': 'http://ww...
# 6876  {'stellar_mocks': {'image_subhalo': 'http://ww...
# 6877  {'stellar_mocks': {'image_subhalo': 'http://ww...
# 6878  {'stellar_mocks': {'image_subhalo': 'http://ww...
# 6879  {'stellar_mocks': {'image_subhalo': 'http://ww...
# 6880  {'stellar_mocks': {'image_subhalo': 'http://ww...
# 6881  {'stellar_mocks': {'image_subhalo': 'http://ww...
# 6882  {'stellar_mocks': {'image_subhalo': 'http://ww...
# 6883  {'stellar_mocks': {'image_subhalo': 'http://ww...
# 6884  {'stellar_mocks': {'image_subhalo': 'http://ww...
# 6885  {'stellar_mocks': {'image_subhalo': 'http://ww...
# 6886  {'stellar_mocks': {'image_subhalo': 'http://ww...
# 6887  {'stellar_mocks': {'image_subhalo': 'http://ww...
# 6888  {'stellar_mocks': {'image_subhalo': 'http://ww...
# 6889  {'stellar_mocks': {'image_subhalo': 'http://ww...
# 6890  {'stellar_mocks': {'image_subhalo': 'http://ww...
#
#                                                   trees      vel_x      vel_y  \
# 0     {'sublink_mpb': 'http://www.illustris-project....    25.2801  -217.0670
# 1     {'sublink_mpb': 'http://www.illustris-project....    77.8400   599.7980
# 2     {'sublink_mpb': 'http://www.illustris-project....   309.6180  -565.6190
# 3     {'sublink_mpb': 'http://www.illustris-project....  -331.8870  -870.3290
# 4     {'sublink_mpb': 'http://www.illustris-project....    62.9793 -1138.3000
# 5     {'sublink_mpb': 'http://www.illustris-project.... -1208.7000    53.4307
# 6     {'sublink_mpb': 'http://www.illustris-project....   191.5630  -439.4530
# 7     {'sublink_mpb': 'http://www.illustris-project....  -272.7960  -414.9590
# 8     {'sublink_mpb': 'http://www.illustris-project....   526.0520  -616.9760
# 9     {'sublink_mpb': 'http://www.illustris-project....  -518.2040   367.1850
# 10    {'sublink_mpb': 'http://www.illustris-project....   179.6800  -946.8410
# 11    {'sublink_mpb': 'http://www.illustris-project....   -63.9312   -35.7570
# 12    {'sublink_mpb': 'http://www.illustris-project....    62.6311  -371.5720
# 13    {'sublink_mpb': 'http://www.illustris-project....  -626.8020   -74.5805
# 14    {'sublink_mpb': 'http://www.illustris-project....   152.1970  -525.1130
# 15    {'sublink_mpb': 'http://www.illustris-project....  -206.7560  -217.4390
# 16    {'sublink_mpb': 'http://www.illustris-project....  -156.7620   597.4810
# 17    {'sublink_mpb': 'http://www.illustris-project....   221.0400   839.1320
# 18    {'sublink_mpb': 'http://www.illustris-project....  -234.4080   345.6260
# 19    {'sublink_mpb': 'http://www.illustris-project....    60.7729  -420.7640
# 20    {'sublink_mpb': 'http://www.illustris-project....   157.3450  -299.3540
# 21    {'sublink_mpb': 'http://www.illustris-project....   276.8820  -676.1580
# 22    {'sublink_mpb': 'http://www.illustris-project....   123.1300  -698.9820
# 23    {'sublink_mpb': 'http://www.illustris-project....   298.8370   196.5820
# 24    {'sublink_mpb': 'http://www.illustris-project....  -656.7020   276.1070
# 25    {'sublink_mpb': 'http://www.illustris-project....   275.0660  -280.5720
# 26    {'sublink_mpb': 'http://www.illustris-project....  -515.8400   612.2180
# 27    {'sublink_mpb': 'http://www.illustris-project....   238.0230   583.8290
# 28    {'sublink_mpb': 'http://www.illustris-project....  -148.0020  -225.6760
# 29    {'sublink_mpb': 'http://www.illustris-project....   583.9650   330.0310
# ...                                                 ...        ...        ...
# 6861  {'sublink_mpb': 'http://www.illustris-project....  -110.4950   389.2120
# 6862  {'sublink_mpb': 'http://www.illustris-project....   802.0010  -103.8590
# 6863  {'sublink_mpb': 'http://www.illustris-project....  -145.6910   -60.6104
# 6864  {'sublink_mpb': 'http://www.illustris-project....    24.0580   -86.6046
# 6865  {'sublink_mpb': 'http://www.illustris-project....    44.6242  -380.1450
# 6866  {'sublink_mpb': 'http://www.illustris-project....   154.8130    81.2835
# 6867  {'sublink_mpb': 'http://www.illustris-project....  -187.8790  -358.7340
# 6868  {'sublink_mpb': 'http://www.illustris-project....   237.9830   186.1050
# 6869  {'sublink_mpb': 'http://www.illustris-project....  -248.9380    53.1321
# 6870  {'sublink_mpb': 'http://www.illustris-project....  -348.5460    68.0106
# 6871  {'sublink_mpb': 'http://www.illustris-project....  -185.1950   -55.4893
# 6872  {'sublink_mpb': 'http://www.illustris-project....     0.9448   575.4500
# 6873  {'sublink_mpb': 'http://www.illustris-project....  -127.5830    59.2951
# 6874  {'sublink_mpb': 'http://www.illustris-project....   164.7450  -142.2350
# 6875  {'sublink_mpb': 'http://www.illustris-project....   -41.4344   204.5980
# 6876  {'sublink_mpb': 'http://www.illustris-project....   -30.7060   306.0520
# 6877  {'sublink_mpb': 'http://www.illustris-project....    21.5786  -158.0560
# 6878  {'sublink_mpb': 'http://www.illustris-project....  -211.6840    93.0256
# 6879  {'sublink_mpb': 'http://www.illustris-project....   -61.7451   225.1720
# 6869  -266.3090   55.4179  107.623   11.4621  0.001758
# 6870   163.8330   65.2799  126.140   14.2070  0.006691
# 6871  -148.0690   68.3820  133.309   12.0589  0.000372
# 6872   698.4920   70.9709  140.481    8.8595  0.003929
# 6873   218.3110   62.9786  122.176   12.0421  0.006275
# 6874   -73.0121   59.1677  117.249   12.3040  0.005524
# 6875   657.3920   65.7715  131.302   10.5512  0.004277
# 6876   -80.1129   60.6157  116.560   15.7301  0.001372
# 6877   -61.6954   62.1356  121.163   14.8691  0.012405
# 6878  -288.5420   66.0187  126.321   12.0492  0.015928
# 6879    -6.8588   60.7390  116.869   13.0327  0.001081
# 6880    77.0470   66.0614  126.228   10.6357  0.002037
# 6881  -603.0910   61.5950  118.831   14.6152  0.003687
# 6882  -180.0460   68.8805  133.830   10.1076  0.002372
# 6883   198.9710   66.4453  128.841   11.8621  0.001610
# 6884   135.0550   67.3850  129.083   13.1434  0.001374
# 6885     9.8268   59.2406  115.813   12.1204  0.015404
# 6886    62.7364   53.2580  107.057   10.1408  0.001303
# 6887  -117.7000   61.9538  121.821    8.8900  0.000000
# 6888     6.4813   65.7880  128.867   10.0812  0.012778
# 6889   531.1680   60.3921  120.312    8.4030  0.009561
# 6890   -50.6729   58.1926  114.856    6.5384  0.000000
#
# [6891 rows x 84 columns]

# %% [markdown]
# ## Retrieve data for galaxies that were classified in Galaxy Zoo II from SciServer
# **Notes**:
# The SDSS database lists numerous measurements and derived estimates of the **apparent** magnitude for many galaxies in its dataset. Here the magnitude computed within the **petrosian** radius in each of the SDSS bands (u,g,r,i,z) is used.
#
# Apparent magnitudes are converted to an **absolute** magnitude using the function `fCosmoAbsMag` provided by the SDSS database server. Default values are used for the cosmological description which correspoond with WMAP-5 values. In contrast, the Illustris simulation framework assumes the WMAP-9 values for its cosmological simulation. Since the selected galaxies all have 0.04 < z < 0.06 and the zero-redshift slice of the Illustris simulation was used, this discrepancy should not be problematic.
#
# Vote fraction "probabilities" derived from Galaxy Zoo classifications are also extracted for all galaxies.

# %% [markdown]
# ### Form a query that assembles data from various tables and views using database joins.

# %%
sdssDataBaseQuery = """SELECT spec.z, spec.zErr, spec.zWarning, 
spec.petroMag_u, spec.petroMag_g, spec.petroMag_r, spec.petroMag_i, spec.petroMag_z,   
dbo.fCosmoAbsMag(spec.petroMag_u,spec.z,DEFAULT,DEFAULT,DEFAULT,DEFAULT,DEFAULT) as absPetroMag_u,
dbo.fCosmoAbsMag(spec.petroMag_g,spec.z,DEFAULT,DEFAULT,DEFAULT,DEFAULT,DEFAULT) as absPetroMag_g,
dbo.fCosmoAbsMag(spec.petroMag_r,spec.z,DEFAULT,DEFAULT,DEFAULT,DEFAULT,DEFAULT) as absPetroMag_r,
dbo.fCosmoAbsMag(spec.petroMag_i,spec.z,DEFAULT,DEFAULT,DEFAULT,DEFAULT,DEFAULT) as absPetroMag_i,
dbo.fCosmoAbsMag(spec.petroMag_z,spec.z,DEFAULT,DEFAULT,DEFAULT,DEFAULT,DEFAULT) as absPetroMag_z,
zooSpecExtra.* FROM 
(
SELECT 
zoo.objid, zoo.dr7objid, zoo.ra, zoo.dec, zoo.rastring, zoo.decstring, zoo.nvote, 
zoo.p_el, zoo.p_cw, zoo.p_acw, zoo.p_edge, zoo.p_dk, zoo.p_mg, zoo.p_cs, zoo.p_el_debiased, zoo.p_cs_debiased,
spiral, zoo.elliptical, zoo.uncertain, specExtra.*
FROM zooSpec AS zoo 
LEFT JOIN 
galSpecExtra AS specExtra 
ON (specExtra.specObjID = zoo.specobjid) 
) 
AS zooSpecExtra 
LEFT JOIN
SpecPhoto AS spec 
ON 
(spec.specObjID = zooSpecExtra.specobjid) 
WHERE 
(spec.z > 0.04 AND spec.z < 0.06)
"""

# %% [markdown]
# ### Execute the query using the SciServer CasJobs API
# Note that **Data release 8** (`dr8`) must be specified as the query context, since extiates of stellar mass and star formation rate (retrieved from the `specExtra` table) do not exist for later releases.
#
# The SciServer CasJobs API returns query results as a `pandas.DataFrame`, so no additional data manipulation is required once the API returns.

# %%
sdssDataBaseQueryResult = None
if saveGalaxyZooSDSSDataFrame :
    galaxyZooSDSSDataFrame = CasJobs.executeQuery(sdssDataBaseQuery, "dr8", token=sciServerAuthToken)
    galaxyZooSDSSDataFrame.to_pickle(galaxyZooSDSSDataFramePath)
else :
    pickleDataFile = open(galaxyZooSDSSDataFramePath, mode='rb')
    galaxyZooSDSSDataFrame = pickle.load(pickleDataFile) 
    pickleDataFile.close()
    
if verbose :
    display(galaxyZooSDSSDataFrame)
    prettyPrinter.pprint(galaxyZooSDSSDataFrame.columns.values)
# Out:
#               z      zErr  zWarning  petroMag_u  petroMag_g  petroMag_r  \
# 0      0.047390  0.000020         0    18.67079    17.76282    17.46165
# 1      0.055152  0.000009         0    19.14275    17.80085    17.32876
# 2      0.051137  0.000008         0    19.11676    17.95765    17.50110
# 3      0.046470  0.000021         0    19.70397    18.12540    17.37514
# 4      0.045730  0.000020         0    19.06302    17.71498    16.88320
# 5      0.045845  0.000009         0    18.64579    17.13083    16.38492
# 6      0.046778  0.000010         0    18.68350    17.55574    17.25553
# 7      0.046215  0.000016         0    18.82331    18.03938    17.54173
# 8      0.047013  0.000007         0    17.35256    16.27303    15.80755
# 9      0.046997  0.000013         0    16.32964    14.92287    14.29989
# 10     0.047410  0.000013         0    19.15216    17.93654    17.44177
# 11     0.040514  0.000005         0    17.92863    17.06864    16.89101
# 12     0.046387  0.000010         0    19.37716    18.10389    17.43019
# 13     0.043137  0.000005         0    17.68552    16.64925    16.22328
# 14     0.042647  0.000015         0    18.75295    17.55986    17.12875
# 15     0.040158  0.000012         0    18.88299    17.79710    17.19110
# 16     0.042392  0.000012         0    18.15040    16.37996    15.57679
# 17     0.042079  0.000014         0    19.25027    17.95682    17.31511
# 18     0.043511  0.000009         0    18.89803    17.68151    17.21026
# 19     0.043238  0.000006         0    19.14862    18.10933    17.65713
# 20     0.043503  0.000009         0    17.16378    16.14612    15.79926
# 21     0.040618  0.000006         0    18.75173    17.80368    17.44980
# 22     0.055372  0.000014         0    19.09316    17.53143    16.77489
# 23     0.050566  0.000017         0    18.78126    17.65540    17.12880
# 24     0.049904  0.000021         0    19.80398    18.13773    17.29781
# 25     0.046662  0.000012         0    17.78929    16.07803    15.12002
# 26     0.047195  0.000008         0    18.93479    18.03305    17.65366
# 27     0.049168  0.000009         0    19.22559    17.98921    17.50209
# 28     0.049399  0.000012         0    19.51868    17.89171    17.13383
# 29     0.044847  0.000013         0    18.67374    16.66310    15.93394
# 24            ...                -11.532330       -10.873260
# 25            ...                -12.551190       -11.716230
# 26            ...              -9999.000000     -9999.000000
# 27            ...                 -9.977625        -9.688919
# 28            ...                -10.099200        -9.898917
# 29            ...                -10.757740       -10.355810
# ...           ...                       ...              ...
# 63796         ...                 -9.785841        -9.549733
# 63797         ...                 -9.506019        -9.153226
# 63798         ...                -11.936780       -11.113000
# 63799         ...                -11.620510       -10.936040
# 63800         ...                -10.776330       -10.228070
# 63801         ...                 -9.501407        -9.164465
# 63802         ...                -11.413260       -10.836320
# 63803         ...                 -9.455614        -9.300933
# 63804         ...                 -9.417963        -9.105806
# 63805         ...                -10.262390        -9.947369
# 63806         ...                 -9.785454        -9.411206
# 63807         ...                -10.048070        -9.771069
# 63808         ...                 -9.670655        -9.334797
# 63809         ...                 -9.800736        -9.537560
# 63810         ...                 -9.975966        -9.651515
# 63811         ...                -10.510610       -10.050750
# 63812         ...                -10.341100        -9.859615
# 63813         ...                -11.474540       -10.823480
# 63814         ...                -11.760000       -11.030460
# 63815         ...                -10.612350       -10.231250
# 63816         ...                -10.150280        -9.847429
# 63817         ...                 -9.921336        -9.630151
# 63818         ...                -10.414580       -10.000000
# 63819         ...                -10.066550        -9.725715
# 63820         ...                -10.200180       -10.006750
# 63821         ...                -11.438160       -10.786320
# 63822         ...                -11.980950       -11.125680
# 63823         ...                -12.251870       -11.273530
# 63824         ...                 -9.951459        -9.676923
# 63825         ...                 -9.765961        -9.418874
#
#        specsfr_tot_p97p5  specsfr_tot_entropy  specsfr_fib_p2p5  \
# 0              -9.252631            -5.030650        -12.210000
# 1              -9.403658            -4.290216        -10.372060
# 2              -8.948529            -5.196127        -10.234940
# 3             -10.171740            -6.281250        -14.073910
# 4              -9.557575            -5.246788        -13.719440
# 5              -9.618519            -5.605923        -11.613330
# 6              -8.950000            -4.670605        -10.470830
# 7              -9.157894            -5.034403        -10.637390
# 8              -9.247499            -4.197042         -9.930120
# 9             -10.593480            -6.391726        -14.593750
# 10             -9.327941            -4.838497        -10.682140
# 11             -8.577026            -4.530396         -9.835976
# 12             -9.492308            -5.320982        -11.104550
# 13             -8.862500            -4.386591         -9.934896
# 14             -8.978571            -4.761679        -11.175000
# 15             -9.472973            -5.012366        -11.387500
# 16            -10.612120            -6.334582        -14.438890
# 17             -9.617857            -4.955079        -11.284610
# 18             -9.214516            -4.537097        -10.260710
# 19             -9.295454            -3.718128         -9.751961
# 20             -9.416216            -4.633361        -10.035710
# 21             -8.921621            -5.645185        -10.311720
# 22            -10.057140            -5.887267        -13.733330
# 23             -9.427000            -4.631393        -11.770000
# 24            -10.361910            -6.192035        -14.106670
# 25            -11.004170            -6.280266        -14.657140
# 26          -9999.000000         -9999.000000      -9999.000000
# 27             -9.340322            -4.469914        -10.480320
# 28             -9.688235            -4.028382        -10.033120
# 29             -9.933332            -5.464557        -13.386360
# ...                  ...                  ...               ...
# 63796          -9.110416            -4.195798        -10.016430
# 63797          -8.655999            -4.683190        -10.310390
# 63798         -10.510870            -6.357309        -14.485710
# 63799         -10.396000            -6.251775        -14.291180
#        'petroMag_i', 'petroMag_z', 'absPetroMag_u', 'absPetroMag_g',
#        'absPetroMag_r', 'absPetroMag_i', 'absPetroMag_z', 'objid',
#        'dr7objid', 'ra', 'dec', 'rastring', 'decstring', 'nvote', 'p_el',
#        'p_cw', 'p_acw', 'p_edge', 'p_dk', 'p_mg', 'p_cs', 'p_el_debiased',
#        'p_cs_debiased', 'spiral', 'elliptical', 'uncertain', 'specObjID',
#        'bptclass', 'oh_p2p5', 'oh_p16', 'oh_p50', 'oh_p84', 'oh_p97p5',
#        'oh_entropy', 'lgm_tot_p2p5', 'lgm_tot_p16', 'lgm_tot_p50',
#        'lgm_tot_p84', 'lgm_tot_p97p5', 'lgm_fib_p2p5', 'lgm_fib_p16',
#        'lgm_fib_p50', 'lgm_fib_p84', 'lgm_fib_p97p5', 'sfr_tot_p2p5',
#        'sfr_tot_p16', 'sfr_tot_p50', 'sfr_tot_p84', 'sfr_tot_p97p5',
#        'sfr_tot_entropy', 'sfr_fib_p2p5', 'sfr_fib_p16', 'sfr_fib_p50',
#        'sfr_fib_p84', 'sfr_fib_p97p5', 'sfr_fib_entropy',
#        'specsfr_tot_p2p5', 'specsfr_tot_p16', 'specsfr_tot_p50',
#        'specsfr_tot_p84', 'specsfr_tot_p97p5', 'specsfr_tot_entropy',
#        'specsfr_fib_p2p5', 'specsfr_fib_p16', 'specsfr_fib_p50',
#        'specsfr_fib_p84', 'specsfr_fib_p97p5', 'specsfr_fib_entropy'], dtype=object)

# %% [markdown]
# ## Manipulate the Illustris galaxy data as appropriate and compare with SDSS properties
# ### The distribution of stellar masses

# %%
hubbleConstant = 0.74

# %%
illustrisStellarMasses = np.log10(10**10*(fullIllustrisWebServiceDataFrame["mass_stars"]/hubbleConstant))
illustrisStellarMasses.plot.hist(bins=50, histtype='step', logy=True, fill=False, color='r')
plt.xlabel(r'$\log(M_{\star})$', size=15)

# %% [markdown]
# ### The distributions of absolute magnitudes in the SDSS (u, g, r, i, z) bands

# %%
magLimits = {'u':22,
             'g':22.2,
             'r': 17.77,
             'i':21.3,
             'z':20.5}

illustrisAbsMagFigure = plt.figure(figsize=(15, 15))
illustrisAbsMagFigure.suptitle('Illustris Absolute Magnitudes', size=12)

for index, value in enumerate(['u','g','r','i','z']) :
    subplotAxis = plt.subplot(3, 2, index+1)
    fullIllustrisWebServiceDataFrame['stellarphotometrics_' + value].plot.hist(ax=subplotAxis, normed=True, bins=50, histtype='step', logy=True, fill=False, color='r')
    galaxyZooSDSSDataFrame[np.logical_and(galaxyZooSDSSDataFrame['absPetroMag_r'] > -9000, np.logical_and(galaxyZooSDSSDataFrame['petroMag_' + value] < magLimits[value], galaxyZooSDSSDataFrame['lgm_tot_p97p5'] > 10))][['absPetroMag_' + value]].plot.hist(normed=True, ax=subplotAxis, bins=50, histtype='step', logy=True, fill=False, label='SDSS ' + value.upper(), color='b')
    lines, labels = subplotAxis.get_legend_handles_labels()
    labels = ['Illustris ' + str(value.upper()), 'SDSS ' + str(value.upper())]
    subplotAxis.legend(lines[:2], labels[:2], loc='best')
    plt.xlabel("Absolute magnitude")
