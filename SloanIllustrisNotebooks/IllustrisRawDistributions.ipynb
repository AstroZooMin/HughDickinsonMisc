# %% [markdown]
# # Galaxy property distributions for all galaxies in the GZ Illustris dataset

# %% [markdown]
# ## Module Imports

# %%
import SciServer.CasJobs as CasJobs # query with CasJobs
import SciServer.SciDrive           # read/write to/from SciDrive
import SciServer.LoginPortal

# %%
from pymongo import MongoClient
from bson.son import SON
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import astropy.io.fits as astrofits
from astropy.table import Table
import scipy
from scipy import interpolate
import pickle
import skimage.io 
import urllib3
import io
import requests
import gc # needed because the pandas plotting routines open too many files and cause crashes (maybe also mongo)
# %matplotlib inline

# %% [markdown]
# ## Initial Setup

# %% [markdown]
# ### Control output verbosity and enable foratted prinding of data structures

# %%
verbose = True
if verbose :
    import pprint
    from IPython.core.display import display
    prettyPrinter = pprint.PrettyPrinter(indent=4)

# %% [markdown]
# ### Credentials and static variables for Illustris Web Service
# This API key should not require updating.

# %%
illustrisAPIKey="44ddc0a0574472a27514600007f1a6a1"
illustrisBaseUrl = 'http://www.illustris-project.org/api/'
illustrisHeaders = {"api-key":illustrisAPIKey}

# %% [markdown]
# ### Utility function for performing queries of the Illustris web service

# %%
def illustrisGet(path, params = None, headers = None):
    # make HTTP GET request to path
    r = requests.get(path, params=params, headers=headers)
    
    # raise exception if response code is not HTTP SUCCESS (200)
    r.raise_for_status()
    
    if r.headers['content-type'] == 'application/json':
        return r.json() # parse json responses automatically
    return r

# %% [markdown]
# ### Credentials for SDSS CasJobs/SciServer interface
# This key must be updated every time that the SciServer logout/login cycle occurs.

# %%
sciServerAuthToken = 'db3c963fdf1f42c79b490b9a54f58821'
SciServer.LoginPortal.setKeystoneToken(sciServerAuthToken)
userManager = SciServer.LoginPortal.getKeystoneUserWithToken(sciServerAuthToken)

# %% [markdown]
# ### Variables pertaining to local  `mongodb` Galaxy Zoo classifications database

# %%
clientInstance = MongoClient()
database = clientInstance['test']
gzClassifications = database['galaxy_zoo_classifications']
gzSubjects = database['galaxy_zoo_subjects']
gzGroups = database['galaxy_zoo_groups']

# %% [markdown]
# ### Variables that control serialization and loading of data extracted from the GZ mongo database

# %%
saveFullIllustrisMongoDataFrame = False
fullIllustrisMongoDataFramePath = '/Users/hughdickinson/Documents/Development/Sloan-Illustris-Comparison/data/FullIllustrisMongoDataFrame.pkl'

# %% [markdown]
# ### Variables that control serialization and loading of data downloaded from the Illustris Web Service

# %%
saveFullIllustrisWebServiceDataFrame = False
fullIllustrisWebServiceDataFramePath = '/Users/hughdickinson/Documents/Development/Sloan-Illustris-Comparison/data/FullIllustrisWebServiceDataFrame.pkl'

# %% [markdown]
# ### Variables that control serialization and loading of GZ-related data downloaded from the SDSS SkyServer

# %%
saveGalaxyZooSDSSDataFrame = False
galaxyZooSDSSDataFramePath = '/Users/hughdickinson/Documents/Development/Sloan-Illustris-Comparison/data/GalaxyZooSDSSDataFrame.pkl'

# %% [markdown]
# ## Query `mongodb` database to retrieve subjects for the *illustris* survey

# %%
fullIllustrisMongoDataFrame = None

if saveFullIllustrisMongoDataFrame:
    fullIllustrisMongoData = list(gzSubjects.find({"metadata.survey": "illustris"}, 
                                                     {"metadata": 1, "state" : 1, "location": 1}))
    
    fullIllustrisMongoDataFrame = pd.DataFrame([ (
                fullIllustrisMongoDatum["metadata"]["subhalo_id"],
                fullIllustrisMongoDatum["metadata"]["priority"],
                fullIllustrisMongoDatum["state"],
                fullIllustrisMongoDatum["location"]["standard"],
                fullIllustrisMongoDatum["location"],
                fullIllustrisMongoDatum["metadata"]
            ) for fullIllustrisMongoDatum in fullIllustrisMongoData],
                                               columns=["subhalo_id",
                                                        "priority",
                                                        "state", 
                                                        "standard_location",
                                                        "all_location_data",
                                                        "all_metadata"]
                                              )
        
    fullIllustrisMongoDataFrame.to_pickle(fullIllustrisMongoDataFramePath)
else :
    pickleDataFile = open(fullIllustrisMongoDataFramePath, mode='rb')
    fullIllustrisMongoDataFrame = pickle.load(pickleDataFile) 
    pickleDataFile.close()
    
if verbose :
    display (fullIllustrisMongoDataFrame)
# Out:
#         subhalo_id     priority     state  \
# 0               25   fixed_view  complete
# 1               26   fixed_view  complete
# 2               27   fixed_view  complete
# 3               28   fixed_view  complete
# 4               29   fixed_view  complete
# 5               40   fixed_view  complete
# 6               45   fixed_view  complete
# 7               46   fixed_view  complete
# 8               47   fixed_view  complete
# 9               48   fixed_view  complete
# 10              49   fixed_view  complete
# 11              41   fixed_view  complete
# 12               0   fixed_view  complete
# 13               1   fixed_view  complete
# 14              10   fixed_view  complete
# 15             101   fixed_view  complete
# 16             102   fixed_view  complete
# 17               3   fixed_mass  complete
# 18              30   fixed_view  complete
# 19              31   fixed_view  complete
# 20              32   fixed_view  complete
# 21              33   fixed_view  complete
# 22              34   fixed_view  complete
# 23              35   fixed_view  complete
# 24              36   fixed_view  complete
# 25              37   fixed_view  complete
# 26              38   fixed_view  complete
# 27              39   fixed_view  complete
# 28               4   fixed_mass  complete
# 29              42   fixed_view  complete
# ...            ...          ...       ...
# 110226      519479  full_sample    paused
# 110227      518759  full_sample    paused
# 110228      519747  full_sample    paused
# 110229      520188  full_sample    paused
# 110230      520742  full_sample    paused
# 110231      520784  full_sample    paused
# 110232      521420  full_sample    paused
# 110233      521231  full_sample    paused
# 110234      521913  full_sample    paused
# 110235      521442  full_sample    paused
# 110236      521931  full_sample    paused
# 110237      522517  full_sample    paused
# 110238      523126  full_sample    paused
# 110239      524084  full_sample    paused
# 110240      524223  full_sample    paused
# 110241      524679  full_sample    paused
# 110242      524364  full_sample    paused
# 110243      525000  full_sample    paused
# 110244      525174  full_sample    paused
# 110245      525710  full_sample    paused
# 110246      526410  full_sample    paused
# 110247      526649  full_sample    paused
# 110248      527538  full_sample    paused
# 110249      529353  full_sample    paused
# 110250      530404  full_sample    paused
# 110251      530529  full_sample    paused
# 110252      538541  full_sample    paused
# 110253      525516   fixed_mass  complete
# 110254      527544  full_sample    paused
# 110255      543284  full_sample    paused
#
#                                         standard_location  \
# 0       http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 1       http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 2       http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 3       http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 4       http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 5       http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 6       http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 7       http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 8       http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 9       http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 10      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 11      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 12      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 13      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 14      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 15      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 16      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 17      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 18      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 19      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 20      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 21      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 22      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 23      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 24      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 25      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 26      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 27      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 28      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 29      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# ...                                                   ...
# 110226  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110227  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110228  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110229  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110230  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110231  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110232  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110233  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110234  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110235  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110236  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110237  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110238  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110239  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110240  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110241  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110242  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110243  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110244  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110245  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110246  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110247  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110248  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110249  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110250  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110251  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110252  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110253  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110254  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110255  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
#
#                                         all_location_data  \
# 0       {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 1       {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 2       {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 3       {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 4       {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 5       {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 6       {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 7       {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 8       {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 9       {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 10      {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 11      {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 12      {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 13      {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 14      {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 15      {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 16      {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 17      {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 18      {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 19      {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 20      {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 21      {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 22      {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 23      {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 24      {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 25      {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 26      {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 27      {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 28      {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 29      {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# ...                                                   ...
# 110226  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110227  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110228  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110229  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110230  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110231  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110232  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110233  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110234  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110235  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110236  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110237  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110238  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110239  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110240  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110241  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110242  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110243  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110244  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110245  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110246  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110247  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110248  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110249  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110250  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110251  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110252  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110253  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110254  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110255  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
#
#                                              all_metadata
# 0       {'radius_half': 9.2236, 'subhalo_id': 25, 'pri...
# 1       {'radius_half': 32.0453, 'subhalo_id': 26, 'pr...
# 2       {'radius_half': 33.2924, 'subhalo_id': 27, 'pr...
# 3       {'radius_half': 38.7566, 'subhalo_id': 28, 'pr...
# 4       {'radius_half': 11.2812, 'subhalo_id': 29, 'pr...
# 5       {'radius_half': 24.6295, 'subhalo_id': 40, 'pr...
# 6       {'radius_half': 21.6691, 'subhalo_id': 45, 'pr...
# 7       {'radius_half': 20.1613, 'subhalo_id': 46, 'pr...
# 8       {'radius_half': 24.6924, 'subhalo_id': 47, 'pr...
# 9       {'radius_half': 15.8815, 'subhalo_id': 48, 'pr...
# 10      {'radius_half': 30.0755, 'subhalo_id': 49, 'pr...
# 11      {'radius_half': 18.9961, 'subhalo_id': 41, 'pr...
# 12      {'radius_half': 655.851, 'subhalo_id': 0, 'pri...
# 13      {'radius_half': 290.407, 'subhalo_id': 1, 'pri...
# 14      {'radius_half': 32.4016, 'subhalo_id': 10, 'pr...
# 15      {'radius_half': 13.5447, 'subhalo_id': 101, 'p...
# 16      {'radius_half': 15.6641, 'subhalo_id': 102, 'p...
# 17      {'radius_half': 38.8213, 'subhalo_id': 3, 'pri...
# 18      {'radius_half': 11.1234, 'subhalo_id': 30, 'pr...
# 19      {'radius_half': 30.4318, 'subhalo_id': 31, 'pr...
# 20      {'radius_half': 35.6398, 'subhalo_id': 32, 'pr...
# 21      {'radius_half': 26.8884, 'subhalo_id': 33, 'pr...
# 22      {'radius_half': 32.3738, 'subhalo_id': 34, 'pr...
# 23      {'radius_half': 27.3122, 'subhalo_id': 35, 'pr...
# 24      {'radius_half': 19.3509, 'subhalo_id': 36, 'pr...
# 25      {'radius_half': 7.8985, 'subhalo_id': 37, 'pri...
# 26      {'radius_half': 19.8963, 'subhalo_id': 38, 'pr...
# 27      {'radius_half': 31.4879, 'subhalo_id': 39, 'pr...
# 28      {'radius_half': 61.4169, 'subhalo_id': 4, 'pri...
# 29      {'radius_half': 22.5972, 'subhalo_id': 42, 'pr...
# ...                                                   ...
# 110226  {'radius_half': 23.3361, 'subhalo_id': 519479,...
# 110227  {'radius_half': 29.1495, 'subhalo_id': 518759,...
# 110228  {'radius_half': 28.5171, 'subhalo_id': 519747,...
# 110229  {'radius_half': 24.927, 'subhalo_id': 520188, ...
# 110230  {'radius_half': 24.4178, 'subhalo_id': 520742,...
# 110231  {'radius_half': 24.9356, 'subhalo_id': 520784,...
# 110232  {'radius_half': 21.0821, 'subhalo_id': 521420,...
# 110233  {'radius_half': 31.3105, 'subhalo_id': 521231,...
# 110234  {'radius_half': 22.2775, 'subhalo_id': 521913,...
# 110235  {'radius_half': 28.8396, 'subhalo_id': 521442,...
# 110236  {'radius_half': 13.6628, 'subhalo_id': 521931,...
# 110237  {'radius_half': 26.2131, 'subhalo_id': 522517,...
# 110238  {'radius_half': 23.1894, 'subhalo_id': 523126,...
# 110239  {'radius_half': 19.1733, 'subhalo_id': 524084,...
# 110240  {'radius_half': 24.5679, 'subhalo_id': 524223,...
# 110241  {'radius_half': 19.1102, 'subhalo_id': 524679,...
# 110242  {'radius_half': 25.0581, 'subhalo_id': 524364,...
# 110243  {'radius_half': 22.974, 'subhalo_id': 525000, ...
# 110244  {'radius_half': 22.5409, 'subhalo_id': 525174,...
# 110245  {'radius_half': 20.0414, 'subhalo_id': 525710,...
# 110246  {'radius_half': 17.5181, 'subhalo_id': 526410,...
# 110247  {'radius_half': 18.4408, 'subhalo_id': 526649,...
# 110248  {'radius_half': 23.5839, 'subhalo_id': 527538,...
# 110249  {'radius_half': 21.4318, 'subhalo_id': 529353,...
# 110250  {'radius_half': 20.2469, 'subhalo_id': 530404,...
# 110251  {'radius_half': 23.6313, 'subhalo_id': 530529,...
# 110252  {'radius_half': 16.0591, 'subhalo_id': 538541,...
# 110253  {'radius_half': 13.4318, 'subhalo_id': 525516,...
# 110254  {'radius_half': 23.9597, 'subhalo_id': 527544,...
# 110255  {'radius_half': 18.0733, 'subhalo_id': 543284,...
#
# [110256 rows x 6 columns]

# %% [markdown]
# ## Retrieve data for all *unique* database-retrieved subhalo IDs from the Illustris Web Service

# %%
fullIllustrisWebServiceDataFrame = None

if saveFullIllustrisWebServiceDataFrame :
    
    fullIllustrisWebServiceData = []
    
    illustris1SimulationUrl = [ entry['url'] for entry in illustrisGet(illustrisBaseUrl, headers=illustrisHeaders)['simulations'] if entry['name'] == 'Illustris-1'][0]
    illustris1SnapshotsUrl = illustrisGet(illustris1SimulationUrl, headers=illustrisHeaders)['snapshots']
    illustris1ZeroRedshiftSnapshotUrl = illustrisGet(illustris1SnapshotsUrl, headers=illustrisHeaders)[-1]['url']
    illustris1ZeroRedshiftSubHalosUrl = illustrisGet(illustris1ZeroRedshiftSnapshotUrl, headers=illustrisHeaders)['subhalos']

    if verbose :
        print('Base URL for Illustris-1 Simulation => {}'.format(illustris1SimulationUrl))
        print('Base URL for Illustris-1 Simulation Snapshots => {}'.format(illustris1SnapshotsUrl))
        print('Base URL for Illustris-1 Simulation Zero Redshift Snapshot => {}'.format(illustris1ZeroRedshiftSnapshotUrl))
        print('Base URL for Illustris-1 Simulation Zero Redshift Halos => {}\n'.format(illustris1ZeroRedshiftSubHalosUrl))

    requiredIllustrisHaloIds = fullIllustrisMongoDataFrame.groupby('subhalo_id').first().index.values
    
    for requiredIllustrisHaloIndex, requiredIllustrisHaloId in enumerate(requiredIllustrisHaloIds) :
        illustris1ZeroRedshiftSubHaloUrl = illustris1ZeroRedshiftSubHalosUrl + str(requiredIllustrisHaloId)
        fullIllustrisWebServiceData.append(illustrisGet(illustris1ZeroRedshiftSubHaloUrl, headers=illustrisHeaders))
        if requiredIllustrisHaloIndex % 100 == 0 :
            print ('Retrieved data for {} of {} halos...'.format(requiredIllustrisHaloIndex, len(requiredIllustrisHaloIds)))
    print ('Retrieved data for {} halos. Done.'.format(requiredIllustrisHaloIndex))
    
    fullIllustrisWebServiceDataFrame = pd.DataFrame(fullIllustrisWebServiceData)

    fullIllustrisWebServiceDataFrame.to_pickle(fullIllustrisWebServiceDataFramePath)
else :
    pickleDataFile = open(fullIllustrisWebServiceDataFramePath, mode='rb')
    fullIllustrisWebServiceDataFrame = pickle.load(pickleDataFile) 
    pickleDataFile.close()  

if verbose :
    display (fullIllustrisWebServiceDataFrame)
# Out:
#             bhmdot       cm_x      cm_y     cm_z  \
# 0     3.244590e-04    887.726  26311.20  18092.8
# 1     1.260800e-06    184.273  24579.40  16865.0
# 2     4.166120e-04    765.316  26758.30  17215.4
# 3     9.907680e-03   1204.510  26492.10  18221.3
# 4     8.635300e-06    994.455  26623.40  17597.5
# 5     8.833150e-03   1120.970  26604.80  18433.7
# 6     3.000000e-10    809.180  26290.80  18199.2
# 7     2.145650e-03   1425.950  26676.90  17298.5
# 8     0.000000e+00   1614.220  26050.70  19822.3
# 9     0.000000e+00    827.883  26417.30  18222.8
# 10    3.889070e-04   1258.960  26786.10  17628.3
# 11    0.000000e+00    329.143  26699.60  19227.7
# 12    0.000000e+00   1662.040  25407.20  18547.3
# 13    0.000000e+00    724.657  26407.50  18167.8
# 14    0.000000e+00    782.242  26766.90  17166.3
# 15    0.000000e+00    520.154  25952.40  18124.1
# 16    0.000000e+00    433.196  24638.60  16831.6
# 17    7.662010e-05  74980.300  24113.70  16476.8
# 18    0.000000e+00    778.404  26279.40  18415.1
# 19    0.000000e+00   1513.320  25558.20  18344.9
# 20    0.000000e+00   1165.210  25946.30  18561.6
# 21    1.060090e-04   1752.900  26011.30  16643.3
# 22    1.166630e-05    946.247  25427.00  19288.2
# 23    1.041530e-05    427.297  25238.30  16531.0
# 24    6.335200e-04   1538.700  25444.90  18639.2
# 25    0.000000e+00    982.526  26712.20  18407.3
# 26    1.415300e-06    789.982  24684.20  17198.9
# 27    4.971900e-05   1883.380  25803.50  20042.7
# 28    0.000000e+00    906.097  25967.90  17724.5
# 29    1.828350e-05  74576.400  24662.60  16555.6
# ...            ...        ...       ...      ...
# 6861  1.506200e-06  19611.300   6142.47  26486.9
# 6862  2.622090e-05   9894.140  50223.90  46379.2
# 6863  5.138000e-07  39328.000  23211.00  51861.1
# 6864  1.347100e-06  20661.300  54069.30  54397.5
# 6865  2.410000e-08  23947.000   7804.39  74653.5
# 6866  4.605000e-07  38843.900  70038.20  38688.9
# 6867  3.180000e-08  24171.900  36385.00  42221.2
# 6868  2.425000e-07  39757.600  65938.60  42241.2
# 6869  1.097000e-07  39081.800  21513.50  48199.3
# 6870  6.740000e-08  19186.500  12036.90  20297.1
# 6871  3.724000e-07  25079.200  68608.00  74177.9
# 6872  2.824300e-06  74281.900  24562.10  16819.8
# 6873  2.797700e-06  62213.600   5260.79  35120.4
# 6874  1.693000e-07  71031.800  22324.50  20554.5
# 6875  6.013000e-07  10134.900  50918.50  44724.6
# 6876  1.075000e-07  29197.300  71248.20  71291.2
# 6877  1.019900e-06  10446.300  19529.90  63018.7
# 6878  3.256000e-07  29850.200   1175.71  72101.9
# 6879  9.870000e-08  33099.800   1308.07  70371.3
# 6880  1.968100e-06  23838.100  31908.50  40508.5
# 6881  4.867000e-07   1149.290  57147.50  63406.7
# 6882  1.370300e-06  23940.200  49674.60  49215.4
# 6883  1.117900e-06  38997.400  21097.50  46850.6
# 6884  1.571000e-07  53723.100  68433.30  26116.1
# 6885  4.772400e-06  66773.200  57498.40  53656.2
# 6886  1.196000e-07  26844.400  17126.80  31211.3
# 6887  1.027000e-07  23711.700  36785.80  44559.9
# 6888  1.403040e-05  25417.000  31159.50  41223.5
# 6889  1.197500e-06    499.903  17268.60  24366.6
# 6890  0.000000e+00  12288.500  50359.20  49222.1
#
#                                                 cutouts  desc_sfid  desc_snap  \
# 0     {'parent_halo': 'http://www.illustris-project....         -1         -1
# 1     {'parent_halo': 'http://www.illustris-project....         -1         -1
# 2     {'parent_halo': 'http://www.illustris-project....         -1         -1
# 3     {'parent_halo': 'http://www.illustris-project....         -1         -1
# 4     {'parent_halo': 'http://www.illustris-project....         -1         -1
# 5     {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6     {'parent_halo': 'http://www.illustris-project....         -1         -1
# 7     {'parent_halo': 'http://www.illustris-project....         -1         -1
# 8     {'parent_halo': 'http://www.illustris-project....         -1         -1
# 9     {'parent_halo': 'http://www.illustris-project....         -1         -1
# 10    {'parent_halo': 'http://www.illustris-project....         -1         -1
# 11    {'parent_halo': 'http://www.illustris-project....         -1         -1
# 12    {'parent_halo': 'http://www.illustris-project....         -1         -1
# 13    {'parent_halo': 'http://www.illustris-project....         -1         -1
# 14    {'parent_halo': 'http://www.illustris-project....         -1         -1
# 15    {'parent_halo': 'http://www.illustris-project....         -1         -1
# 16    {'parent_halo': 'http://www.illustris-project....         -1         -1
# 17    {'parent_halo': 'http://www.illustris-project....         -1         -1
# 18    {'parent_halo': 'http://www.illustris-project....         -1         -1
# 19    {'parent_halo': 'http://www.illustris-project....         -1         -1
# 20    {'parent_halo': 'http://www.illustris-project....         -1         -1
# 21    {'parent_halo': 'http://www.illustris-project....         -1         -1
# 22    {'parent_halo': 'http://www.illustris-project....         -1         -1
# 23    {'parent_halo': 'http://www.illustris-project....         -1         -1
# 24    {'parent_halo': 'http://www.illustris-project....         -1         -1
# 25    {'parent_halo': 'http://www.illustris-project....         -1         -1
# 26    {'parent_halo': 'http://www.illustris-project....         -1         -1
# 27    {'parent_halo': 'http://www.illustris-project....         -1         -1
# 28    {'parent_halo': 'http://www.illustris-project....         -1         -1
# 29    {'parent_halo': 'http://www.illustris-project....         -1         -1
# ...                                                 ...        ...        ...
# 6861  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6862  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6863  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6864  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6865  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6866  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6867  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6868  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6869  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6870  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6871  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6872  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6873  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6874  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6875  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6876  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6877  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6878  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6879  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6880  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6881  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6882  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6883  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6884  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6885  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6886  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6887  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6888  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6889  {'parent_halo': 'http://www.illustris-project....         -1         -1
# 6890  {'parent_halo': 'http://www.illustris-project....         -1         -1
#
#       gasmetallicity  gasmetallicityhalfrad  gasmetallicitymaxrad    ...     \
# 0           0.009294               0.011018              0.007500    ...
# 1           0.032274               0.033691              0.027029    ...
# 2           0.040203               0.041272              0.038959    ...
# 3           0.050764               0.059546              0.054003    ...
# 4           0.023837               0.025455              0.025549    ...
# 5           0.054275               0.054488              0.054275    ...
# 6           0.012316               0.012227              0.012263    ...
# 7           0.041462               0.044658              0.044915    ...
# 8           0.000000               0.000000              0.000000    ...
# 9           0.000000               0.000000              0.000000    ...
# 10          0.051617               0.059555              0.054371    ...
# 11          0.011751               0.011491              0.011525    ...
# 12          0.000000               0.000000              0.000000    ...
# 13          0.000000               0.000000              0.000000    ...
# 14          0.000000               0.000000              0.000000    ...
# 15          0.000000               0.000000              0.000000    ...
# 16          0.000000               0.000000              0.000000    ...
# 17          0.035683               0.047043              0.032874    ...
# 18          0.000000               0.000000              0.000000    ...
# 19          0.065134               0.065134              0.065134    ...
# 20          0.000000               0.000000              0.000000    ...
# 21          0.041668               0.053713              0.043222    ...
# 22          0.037506               0.044152              0.042127    ...
# 23          0.022667               0.033250              0.018437    ...
# 24          0.061614               0.065944              0.068640    ...
# 25          0.000000               0.000000              0.000000    ...
# 26          0.029495               0.044153              0.024210    ...
# 27          0.033422               0.042080              0.029753    ...
# 28          0.049945               0.058511              0.051653    ...
# 29          0.041217               0.048770              0.041170    ...
# ...              ...                    ...                   ...    ...
# 6861        0.017930               0.027662              0.018385    ...
# 6862        0.018256               0.023913              0.018925    ...
# 6863        0.024467               0.030807              0.022703    ...
# 6864        0.021793               0.031875              0.021079    ...
# 6865        0.019587               0.028367              0.018663    ...
# 6866        0.018346               0.027762              0.016230    ...
# 6867        0.017866               0.023291              0.018107    ...
# 6868        0.026410               0.031651              0.027064    ...
# 6869        0.030090               0.036594              0.031339    ...
# 6870        0.018391               0.024350              0.019265    ...
# 6871        0.028371               0.042795              0.026746    ...
# 6872        0.028463               0.035730              0.027749    ...
# 6873        0.026006               0.037954              0.019814    ...
# 6874        0.017550               0.024717              0.017191    ...
# 6875        0.025097               0.034431              0.023808    ...
# 6876        0.021252               0.028727              0.019616    ...
# 6877        0.019761               0.027732              0.017433    ...
# 6878        0.020449               0.029094              0.018878    ...
# 6879        0.020505               0.028441              0.020345    ...
# 6880        0.022954               0.032972              0.023992    ...
# 6881        0.018159               0.026653              0.018219    ...
# 6882        0.024790               0.035949              0.023823    ...
# 6883        0.021425               0.029097              0.021864    ...
# 6884        0.020195               0.028859              0.020550    ...
# 6885        0.019269               0.028406              0.017653    ...
# 6886        0.024670               0.031812              0.025762    ...
# 6887        0.033170               0.034789              0.033316    ...
# 6888        0.025316               0.032258              0.025341    ...
# 6889        0.022521               0.031176              0.024330    ...
# 6890        0.000000               0.000000              0.000000    ...
#
#       stellarphotometricsrad  \
# 0                    37.5182
# 1                    17.3275
# 2                    13.9054
# 3                    19.5589
# 4                    12.5330
# 5                    13.0157
# 6                    13.5273
# 7                    10.2957
# 8                     9.8320
# 9                    11.2121
# 10                   13.5160
# 11                    7.9947
# 12                    7.7907
# 13                   10.8659
# 14                    8.1942
# 15                   10.2811
# 16                    8.0476
# 17                    7.3050
# 18                    8.5736
# 19                    7.8475
# 20                    8.7859
# 21                    7.9675
# 22                    7.2974
# 23                    5.4734
# 24                    6.8014
# 25                    7.2687
# 26                    7.8846
# 27                    6.3877
# 28                    9.4591
# 29                    5.1580
# ...                      ...
# 6861                  4.5652
# 6862                  4.0137
# 6863                  4.8696
# 6864                  3.7662
# 6865                  4.8243
# 6866                  4.3986
# 6867                  3.8526
# 6868                  4.4483
# 6869                  4.0546
# 6870                  3.6707
# 6871                  4.4445
# 6872                  4.6555
# 6873                  4.1751
# 6874                  4.5728
# 6875                  4.7563
# 6876                  4.6579
# 6877                  4.5510
# 6878                  4.0181
# 6879                  4.2556
# 6880                  3.8961
# 6881                  3.1926
# 6882                  4.4893
# 6883                  4.4661
# 6884                  4.2077
# 6885                  4.7818
# 6886                  3.5801
# 6887                  4.0360
# 6888                  4.2359
# 6889                  3.7768
# 6890                  2.9605
#
#                                      supplementary_data  \
# 0     {'stellar_mocks': {'image_fof': 'http://www.il...
# 1     {'stellar_mocks': {'image_fof': 'http://www.il...
# 2     {'stellar_mocks': {'image_fof': 'http://www.il...
# 3     {'stellar_mocks': {'image_fof': 'http://www.il...
# 4     {'stellar_mocks': {'image_fof': 'http://www.il...
# 5     {'stellar_mocks': {'image_fof': 'http://www.il...
# 6     {'stellar_mocks': {'image_fof': 'http://www.il...
# 7     {'stellar_mocks': {'image_fof': 'http://www.il...
# 8     {'stellar_mocks': {'image_fof': 'http://www.il...
# 9     {'stellar_mocks': {'image_fof': 'http://www.il...
# 10    {'stellar_mocks': {'image_fof': 'http://www.il...
# 11    {'stellar_mocks': {'image_fof': 'http://www.il...
# 12    {'stellar_mocks': {'image_fof': 'http://www.il...
# 13    {'stellar_mocks': {'image_fof': 'http://www.il...
# 14    {'stellar_mocks': {'image_fof': 'http://www.il...
# 15    {'stellar_mocks': {'image_fof': 'http://www.il...
# 16    {'stellar_mocks': {'image_fof': 'http://www.il...
# 17    {'stellar_mocks': {'image_fof': 'http://www.il...
# 18    {'stellar_mocks': {'image_fof': 'http://www.il...
# 19    {'stellar_mocks': {'image_fof': 'http://www.il...
# 20    {'stellar_mocks': {'image_fof': 'http://www.il...
# 21    {'stellar_mocks': {'image_fof': 'http://www.il...
# 22    {'stellar_mocks': {'image_fof': 'http://www.il...
# 23    {'stellar_mocks': {'image_fof': 'http://www.il...
# 24    {'stellar_mocks': {'image_fof': 'http://www.il...
# 25    {'stellar_mocks': {'image_fof': 'http://www.il...
# 26    {'stellar_mocks': {'image_fof': 'http://www.il...
# 27    {'stellar_mocks': {'image_fof': 'http://www.il...
# 28    {'stellar_mocks': {'image_fof': 'http://www.il...
# 29    {'stellar_mocks': {'image_fof': 'http://www.il...
# ...                                                 ...
# 6861  {'stellar_mocks': {'image_fof': 'http://www.il...
# 6862  {'stellar_mocks': {'image_fof': 'http://www.il...
# 6863  {'stellar_mocks': {'image_fof': 'http://www.il...
# 6864  {'stellar_mocks': {'image_fof': 'http://www.il...
# 6865  {'stellar_mocks': {'image_fof': 'http://www.il...
# 6866  {'stellar_mocks': {'image_fof': 'http://www.il...
# 6867  {'stellar_mocks': {'image_fof': 'http://www.il...
# 6868  {'stellar_mocks': {'image_fof': 'http://www.il...
# 6869  {'stellar_mocks': {'image_fof': 'http://www.il...
# 6870  {'stellar_mocks': {'image_fof': 'http://www.il...
# 6871  {'stellar_mocks': {'image_fof': 'http://www.il...
# 6872  {'stellar_mocks': {'image_fof': 'http://www.il...
# 6873  {'stellar_mocks': {'image_fof': 'http://www.il...
# 6874  {'stellar_mocks': {'image_fof': 'http://www.il...
# 6875  {'stellar_mocks': {'image_fof': 'http://www.il...
# 6876  {'stellar_mocks': {'image_fof': 'http://www.il...
# 6877  {'stellar_mocks': {'image_fof': 'http://www.il...
# 6878  {'stellar_mocks': {'image_fof': 'http://www.il...
# 6879  {'stellar_mocks': {'image_fof': 'http://www.il...
# 6880  {'stellar_mocks': {'image_fof': 'http://www.il...
# 6881  {'stellar_mocks': {'image_fof': 'http://www.il...
# 6882  {'stellar_mocks': {'image_fof': 'http://www.il...
# 6883  {'stellar_mocks': {'image_fof': 'http://www.il...
# 6884  {'stellar_mocks': {'image_fof': 'http://www.il...
# 6885  {'stellar_mocks': {'image_fof': 'http://www.il...
# 6886  {'stellar_mocks': {'image_fof': 'http://www.il...
# 6887  {'stellar_mocks': {'image_fof': 'http://www.il...
# 6888  {'stellar_mocks': {'image_fof': 'http://www.il...
# 6889  {'stellar_mocks': {'image_fof': 'http://www.il...
# 6890  {'stellar_mocks': {'image_fof': 'http://www.il...
#
#                                                   trees      vel_x      vel_y  \
# 0     {'lhalotree_mpb': 'http://www.illustris-projec...    25.2801  -217.0670
# 1     {'lhalotree_mpb': 'http://www.illustris-projec...    77.8400   599.7980
# 2     {'lhalotree_mpb': 'http://www.illustris-projec...   309.6180  -565.6190
# 3     {'lhalotree_mpb': 'http://www.illustris-projec...  -331.8870  -870.3290
# 4     {'lhalotree_mpb': 'http://www.illustris-projec...    62.9793 -1138.3000
# 5     {'lhalotree_mpb': 'http://www.illustris-projec... -1208.7000    53.4307
# 6     {'lhalotree_mpb': 'http://www.illustris-projec...   191.5630  -439.4530
# 7     {'lhalotree_mpb': 'http://www.illustris-projec...  -272.7960  -414.9590
# 8     {'lhalotree_mpb': 'http://www.illustris-projec...   526.0520  -616.9760
# 9     {'lhalotree_mpb': 'http://www.illustris-projec...  -518.2040   367.1850
# 10    {'lhalotree_mpb': 'http://www.illustris-projec...   179.6800  -946.8410
# 11    {'lhalotree_mpb': 'http://www.illustris-projec...   -63.9312   -35.7570
# 12    {'lhalotree_mpb': 'http://www.illustris-projec...    62.6311  -371.5720
# 13    {'lhalotree_mpb': 'http://www.illustris-projec...  -626.8020   -74.5805
# 14    {'lhalotree_mpb': 'http://www.illustris-projec...   152.1970  -525.1130
# 15    {'lhalotree_mpb': 'http://www.illustris-projec...  -206.7560  -217.4390
# 16    {'lhalotree_mpb': 'http://www.illustris-projec...  -156.7620   597.4810
# 17    {'lhalotree_mpb': 'http://www.illustris-projec...   221.0400   839.1320
# 18    {'lhalotree_mpb': 'http://www.illustris-projec...  -234.4080   345.6260
# 19    {'lhalotree_mpb': 'http://www.illustris-projec...    60.7729  -420.7640
# 20    {'lhalotree_mpb': 'http://www.illustris-projec...   157.3450  -299.3540
# 21    {'lhalotree_mpb': 'http://www.illustris-projec...   276.8820  -676.1580
# 22    {'lhalotree_mpb': 'http://www.illustris-projec...   123.1300  -698.9820
# 23    {'lhalotree_mpb': 'http://www.illustris-projec...   298.8370   196.5820
# 24    {'lhalotree_mpb': 'http://www.illustris-projec...  -656.7020   276.1070
# 25    {'lhalotree_mpb': 'http://www.illustris-projec...   275.0660  -280.5720
# 26    {'lhalotree_mpb': 'http://www.illustris-projec...  -515.8400   612.2180
# 27    {'lhalotree_mpb': 'http://www.illustris-projec...   238.0230   583.8290
# 28    {'lhalotree_mpb': 'http://www.illustris-projec...  -148.0020  -225.6760
# 29    {'lhalotree_mpb': 'http://www.illustris-projec...   583.9650   330.0310
# ...                                                 ...        ...        ...
# 6861  {'lhalotree_mpb': 'http://www.illustris-projec...  -110.4950   389.2120
# 6862  {'lhalotree_mpb': 'http://www.illustris-projec...   802.0010  -103.8590
# 6863  {'lhalotree_mpb': 'http://www.illustris-projec...  -145.6910   -60.6104
# 6864  {'lhalotree_mpb': 'http://www.illustris-projec...    24.0580   -86.6046
# 6865  {'lhalotree_mpb': 'http://www.illustris-projec...    44.6242  -380.1450
# 6866  {'lhalotree_mpb': 'http://www.illustris-projec...   154.8130    81.2835
# 6867  {'lhalotree_mpb': 'http://www.illustris-projec...  -187.8790  -358.7340
# 6868  {'lhalotree_mpb': 'http://www.illustris-projec...   237.9830   186.1050
# 6869  {'lhalotree_mpb': 'http://www.illustris-projec...  -248.9380    53.1321
# 6870  {'lhalotree_mpb': 'http://www.illustris-projec...  -348.5460    68.0106
# 6871  {'lhalotree_mpb': 'http://www.illustris-projec...  -185.1950   -55.4893
# 6872  {'lhalotree_mpb': 'http://www.illustris-projec...     0.9448   575.4500
# 6873  {'lhalotree_mpb': 'http://www.illustris-projec...  -127.5830    59.2951
# 6874  {'lhalotree_mpb': 'http://www.illustris-projec...   164.7450  -142.2350
# 6875  {'lhalotree_mpb': 'http://www.illustris-projec...   -41.4344   204.5980
# 6876  {'lhalotree_mpb': 'http://www.illustris-projec...   -30.7060   306.0520
# 6877  {'lhalotree_mpb': 'http://www.illustris-projec...    21.5786  -158.0560
# 6878  {'lhalotree_mpb': 'http://www.illustris-projec...  -211.6840    93.0256
# 6879  {'lhalotree_mpb': 'http://www.illustris-projec...   -61.7451   225.1720
# 6880  {'lhalotree_mpb': 'http://www.illustris-projec...  -355.1250   621.8910
# 6881  {'lhalotree_mpb': 'http://www.illustris-projec...   124.2930  -131.5510
# 6870   163.8330   65.2799  126.140   14.2070  0.006691
# 6871  -148.0690   68.3820  133.309   12.0589  0.000372
# 6872   698.4920   70.9709  140.481    8.8595  0.003929
# 6873   218.3110   62.9786  122.176   12.0421  0.006275
# 6874   -73.0121   59.1677  117.249   12.3040  0.005524
# 6875   657.3920   65.7715  131.302   10.5512  0.004277
# 6876   -80.1129   60.6157  116.560   15.7301  0.001372
# 6877   -61.6954   62.1356  121.163   14.8691  0.012405
# 6878  -288.5420   66.0187  126.321   12.0492  0.015928
# 6879    -6.8588   60.7390  116.869   13.0327  0.001081
# 6880    77.0470   66.0614  126.228   10.6357  0.002037
# 6881  -603.0910   61.5950  118.831   14.6152  0.003687
# 6882  -180.0460   68.8805  133.830   10.1076  0.002372
# 6883   198.9710   66.4453  128.841   11.8621  0.001610
# 6884   135.0550   67.3850  129.083   13.1434  0.001374
# 6885     9.8268   59.2406  115.813   12.1204  0.015404
# 6886    62.7364   53.2580  107.057   10.1408  0.001303
# 6887  -117.7000   61.9538  121.821    8.8900  0.000000
# 6888     6.4813   65.7880  128.867   10.0812  0.012778
# 6889   531.1680   60.3921  120.312    8.4030  0.009561
# 6890   -50.6729   58.1926  114.856    6.5384  0.000000
#
# [6891 rows x 84 columns]

# %% [markdown]
# ## Create a merged table with stellar masses for all halo IDs

# %%
illustrisStellarMassesFrame = fullIllustrisMongoDataFrame.merge(fullIllustrisWebServiceDataFrame, how='left', left_on='subhalo_id', right_on='id')
display(illustrisStellarMassesFrame)
print (illustrisStellarMassesFrame.columns.values)
# Out:
#         subhalo_id     priority     state  \
# 0               25   fixed_view  complete
# 1               26   fixed_view  complete
# 2               27   fixed_view  complete
# 3               28   fixed_view  complete
# 4               29   fixed_view  complete
# 5               40   fixed_view  complete
# 6               45   fixed_view  complete
# 7               46   fixed_view  complete
# 8               47   fixed_view  complete
# 9               48   fixed_view  complete
# 10              49   fixed_view  complete
# 11              41   fixed_view  complete
# 12               0   fixed_view  complete
# 13               1   fixed_view  complete
# 14              10   fixed_view  complete
# 15             101   fixed_view  complete
# 16             102   fixed_view  complete
# 17               3   fixed_mass  complete
# 18              30   fixed_view  complete
# 19              31   fixed_view  complete
# 20              32   fixed_view  complete
# 21              33   fixed_view  complete
# 22              34   fixed_view  complete
# 23              35   fixed_view  complete
# 24              36   fixed_view  complete
# 25              37   fixed_view  complete
# 26              38   fixed_view  complete
# 27              39   fixed_view  complete
# 28               4   fixed_mass  complete
# 29              42   fixed_view  complete
# ...            ...          ...       ...
# 110226      519479  full_sample    paused
# 110227      518759  full_sample    paused
# 110228      519747  full_sample    paused
# 110229      520188  full_sample    paused
# 110230      520742  full_sample    paused
# 110231      520784  full_sample    paused
# 110232      521420  full_sample    paused
# 110233      521231  full_sample    paused
# 110234      521913  full_sample    paused
# 110235      521442  full_sample    paused
# 110236      521931  full_sample    paused
# 110237      522517  full_sample    paused
# 110238      523126  full_sample    paused
# 110239      524084  full_sample    paused
# 110240      524223  full_sample    paused
# 110241      524679  full_sample    paused
# 110242      524364  full_sample    paused
# 110243      525000  full_sample    paused
# 110244      525174  full_sample    paused
# 110245      525710  full_sample    paused
# 110246      526410  full_sample    paused
# 110247      526649  full_sample    paused
# 110248      527538  full_sample    paused
# 110249      529353  full_sample    paused
# 110250      530404  full_sample    paused
# 110251      530529  full_sample    paused
# 110252      538541  full_sample    paused
# 110253      525516   fixed_mass  complete
# 110254      527544  full_sample    paused
# 110255      543284  full_sample    paused
#
#                                         standard_location  \
# 0       http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 1       http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 2       http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 3       http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 4       http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 5       http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 6       http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 7       http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 8       http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 9       http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 10      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 11      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 12      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 13      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 14      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 15      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 16      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 17      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 18      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 19      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 20      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 21      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 22      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 23      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 24      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 25      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 26      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 27      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 28      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 29      http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# ...                                                   ...
# 110226  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110227  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110228  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110229  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110230  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110231  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110232  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110233  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110234  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110235  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110236  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110237  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110238  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110239  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110240  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110241  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110242  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110243  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110244  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110245  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110246  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110247  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110248  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110249  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110250  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110251  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110252  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110253  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110254  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
# 110255  http://www.galaxyzoo.org.s3.amazonaws.com/subj...
#
#                                         all_location_data  \
# 0       {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 1       {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 2       {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 3       {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 4       {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 5       {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 6       {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 7       {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 8       {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 9       {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 10      {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 11      {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 12      {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 13      {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 14      {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 15      {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 16      {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 17      {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 18      {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 19      {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 20      {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 21      {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 22      {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 23      {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 24      {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 25      {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 26      {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 27      {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 28      {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 29      {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# ...                                                   ...
# 110226  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110227  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110228  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110229  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110230  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110231  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110232  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110233  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110234  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110235  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110236  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110237  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110238  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110239  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110240  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110241  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110242  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110243  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110244  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110245  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110246  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110247  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110248  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110249  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110250  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110251  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110252  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110253  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110254  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
# 110255  {'thumbnail': 'http://www.galaxyzoo.org.s3.ama...
#
#                                              all_metadata        bhmdot  \
# 0       {'radius_half': 9.2236, 'subhalo_id': 25, 'pri...  0.000000e+00
# 1       {'radius_half': 32.0453, 'subhalo_id': 26, 'pr...  1.060090e-04
# 2       {'radius_half': 33.2924, 'subhalo_id': 27, 'pr...  1.166630e-05
# 3       {'radius_half': 38.7566, 'subhalo_id': 28, 'pr...  1.041530e-05
# 4       {'radius_half': 11.2812, 'subhalo_id': 29, 'pr...  6.335200e-04
# 5       {'radius_half': 24.6295, 'subhalo_id': 40, 'pr...  6.892390e-04
# 6       {'radius_half': 21.6691, 'subhalo_id': 45, 'pr...  3.558900e-06
# 7       {'radius_half': 20.1613, 'subhalo_id': 46, 'pr...  3.675720e-04
# 8       {'radius_half': 24.6924, 'subhalo_id': 47, 'pr...  1.210880e-05
# 9       {'radius_half': 15.8815, 'subhalo_id': 48, 'pr...  4.681800e-06
# 10      {'radius_half': 30.0755, 'subhalo_id': 49, 'pr...  5.945000e-07
# 11      {'radius_half': 18.9961, 'subhalo_id': 41, 'pr...  0.000000e+00
# 12      {'radius_half': 655.851, 'subhalo_id': 0, 'pri...  3.244590e-04
# 13      {'radius_half': 290.407, 'subhalo_id': 1, 'pri...  1.260800e-06
# 14      {'radius_half': 32.4016, 'subhalo_id': 10, 'pr...  8.833150e-03
# 15      {'radius_half': 13.5447, 'subhalo_id': 101, 'p...  9.700000e-08
# 16      {'radius_half': 15.6641, 'subhalo_id': 102, 'p...  3.679300e-06
# 17      {'radius_half': 38.8213, 'subhalo_id': 3, 'pri...  9.907680e-03
# 18      {'radius_half': 11.1234, 'subhalo_id': 30, 'pr...  0.000000e+00
# 19      {'radius_half': 30.4318, 'subhalo_id': 31, 'pr...  1.415300e-06
# 20      {'radius_half': 35.6398, 'subhalo_id': 32, 'pr...  4.971900e-05
# 21      {'radius_half': 26.8884, 'subhalo_id': 33, 'pr...  0.000000e+00
# 22      {'radius_half': 32.3738, 'subhalo_id': 34, 'pr...  1.828350e-05
# 23      {'radius_half': 27.3122, 'subhalo_id': 35, 'pr...  1.783520e-04
# 24      {'radius_half': 19.3509, 'subhalo_id': 36, 'pr...  9.323880e-05
# 25      {'radius_half': 7.8985, 'subhalo_id': 37, 'pri...  0.000000e+00
# 26      {'radius_half': 19.8963, 'subhalo_id': 38, 'pr...  1.962990e-05
# 27      {'radius_half': 31.4879, 'subhalo_id': 39, 'pr...  1.288000e-06
# 28      {'radius_half': 61.4169, 'subhalo_id': 4, 'pri...  8.635300e-06
# 29      {'radius_half': 22.5972, 'subhalo_id': 42, 'pr...  2.721000e-07
# ...                                                   ...           ...
# 110226  {'radius_half': 23.3361, 'subhalo_id': 519479,...  1.447000e-07
# 110227  {'radius_half': 29.1495, 'subhalo_id': 518759,...  4.240000e-08
# 110228  {'radius_half': 28.5171, 'subhalo_id': 519747,...  6.090000e-08
# 110229  {'radius_half': 24.927, 'subhalo_id': 520188, ...  6.030000e-08
# 110230  {'radius_half': 24.4178, 'subhalo_id': 520742,...  4.280500e-06
# 110231  {'radius_half': 24.9356, 'subhalo_id': 520784,...  3.700000e-09
# 110232  {'radius_half': 21.0821, 'subhalo_id': 521420,...  1.033350e-05
# 110233  {'radius_half': 31.3105, 'subhalo_id': 521231,...  3.054900e-06
# 110234  {'radius_half': 22.2775, 'subhalo_id': 521913,...  2.600000e-09
# 110235  {'radius_half': 28.8396, 'subhalo_id': 521442,...  1.501000e-07
# 110236  {'radius_half': 13.6628, 'subhalo_id': 521931,...  3.162000e-06
# 110237  {'radius_half': 26.2131, 'subhalo_id': 522517,...  6.465000e-07
# 110238  {'radius_half': 23.1894, 'subhalo_id': 523126,...  1.506200e-06
# 110239  {'radius_half': 19.1733, 'subhalo_id': 524084,...  2.622090e-05
# 110240  {'radius_half': 24.5679, 'subhalo_id': 524223,...  5.138000e-07
# 110241  {'radius_half': 19.1102, 'subhalo_id': 524679,...  2.410000e-08
# 110242  {'radius_half': 25.0581, 'subhalo_id': 524364,...  1.347100e-06
# 110243  {'radius_half': 22.974, 'subhalo_id': 525000, ...  4.605000e-07
# 110244  {'radius_half': 22.5409, 'subhalo_id': 525174,...  3.180000e-08
# 110245  {'radius_half': 20.0414, 'subhalo_id': 525710,...  6.740000e-08
# 110246  {'radius_half': 17.5181, 'subhalo_id': 526410,...  3.724000e-07
# 110247  {'radius_half': 18.4408, 'subhalo_id': 526649,...  2.824300e-06
# 110248  {'radius_half': 23.5839, 'subhalo_id': 527538,...  1.693000e-07
# 110249  {'radius_half': 21.4318, 'subhalo_id': 529353,...  1.019900e-06
# 110239   9894.1400  50223.90  46379.200    ...                    4.0137
# 110240  39328.0000  23211.00  51861.100    ...                    4.8696
# 110241  23947.0000   7804.39  74653.500    ...                    4.8243
# 110242  20661.3000  54069.30  54397.500    ...                    3.7662
# 110243  38843.9000  70038.20  38688.900    ...                    4.3986
# 110244  24171.9000  36385.00  42221.200    ...                    3.8526
# 110245  19186.5000  12036.90  20297.100    ...                    3.6707
# 110246  25079.2000  68608.00  74177.900    ...                    4.4445
# 110247  74281.9000  24562.10  16819.800    ...                    4.6555
# 110248  71031.8000  22324.50  20554.500    ...                    4.5728
# 110249  10446.3000  19529.90  63018.700    ...                    4.5510
# 110250  29850.2000   1175.71  72101.900    ...                    4.0181
# 110251  33099.8000   1308.07  70371.300    ...                    4.2556
# 110252  53723.1000  68433.30  26116.100    ...                    4.2077
# 110253  39081.8000  21513.50  48199.300    ...                    4.0546
# 110254  10134.9000  50918.50  44724.600    ...                    4.7563
# 110255  66773.2000  57498.40  53656.200    ...                    4.7818
#
#                                        supplementary_data  \
# 0       {'stellar_mocks': {'image_fof': 'http://www.il...
# 1       {'stellar_mocks': {'image_fof': 'http://www.il...
# 2       {'stellar_mocks': {'image_fof': 'http://www.il...
# 3       {'stellar_mocks': {'image_fof': 'http://www.il...
# 4       {'stellar_mocks': {'image_fof': 'http://www.il...
# 5       {'stellar_mocks': {'image_fof': 'http://www.il...
# 6       {'stellar_mocks': {'image_fof': 'http://www.il...
# 7       {'stellar_mocks': {'image_fof': 'http://www.il...
# 8       {'stellar_mocks': {'image_fof': 'http://www.il...
# 9       {'stellar_mocks': {'image_fof': 'http://www.il...
# 10      {'stellar_mocks': {'image_fof': 'http://www.il...
# 11      {'stellar_mocks': {'image_fof': 'http://www.il...
# 12      {'stellar_mocks': {'image_fof': 'http://www.il...
# 13      {'stellar_mocks': {'image_fof': 'http://www.il...
# 14      {'stellar_mocks': {'image_fof': 'http://www.il...
# 15      {'stellar_mocks': {'image_fof': 'http://www.il...
# 16      {'stellar_mocks': {'image_fof': 'http://www.il...
# 17      {'stellar_mocks': {'image_fof': 'http://www.il...
# 18      {'stellar_mocks': {'image_fof': 'http://www.il...
# 19      {'stellar_mocks': {'image_fof': 'http://www.il...
# 20      {'stellar_mocks': {'image_fof': 'http://www.il...
# 21      {'stellar_mocks': {'image_fof': 'http://www.il...
# 22      {'stellar_mocks': {'image_fof': 'http://www.il...
# 23      {'stellar_mocks': {'image_fof': 'http://www.il...
# 24      {'stellar_mocks': {'image_fof': 'http://www.il...
# 25      {'stellar_mocks': {'image_fof': 'http://www.il...
# 26      {'stellar_mocks': {'image_fof': 'http://www.il...
# 27      {'stellar_mocks': {'image_fof': 'http://www.il...
# 28      {'stellar_mocks': {'image_fof': 'http://www.il...
# 29      {'stellar_mocks': {'image_fof': 'http://www.il...
# ...                                                   ...
# 110226  {'stellar_mocks': {'sed_subhalo': 'http://www....
# 110227  {'stellar_mocks': {'image_fof': 'http://www.il...
# 110228  {'stellar_mocks': {'image_fof': 'http://www.il...
# 110229  {'stellar_mocks': {'image_fof': 'http://www.il...
# 110230  {'stellar_mocks': {'image_fof': 'http://www.il...
# 110231  {'stellar_mocks': {'image_fof': 'http://www.il...
# 110232  {'stellar_mocks': {'image_fof': 'http://www.il...
# 110233  {'stellar_mocks': {'image_fof': 'http://www.il...
# 110234  {'stellar_mocks': {'image_fof': 'http://www.il...
# 110235  {'stellar_mocks': {'image_fof': 'http://www.il...
# 110236  {'stellar_mocks': {'image_fof': 'http://www.il...
# 110237  {'stellar_mocks': {'image_fof': 'http://www.il...
# 110238  {'stellar_mocks': {'image_fof': 'http://www.il...
# 110239  {'stellar_mocks': {'image_fof': 'http://www.il...
# 110240  {'stellar_mocks': {'image_fof': 'http://www.il...
# 110241  {'stellar_mocks': {'image_fof': 'http://www.il...
# 110242  {'stellar_mocks': {'image_fof': 'http://www.il...
# 110243  {'stellar_mocks': {'image_fof': 'http://www.il...
# 110244  {'stellar_mocks': {'image_fof': 'http://www.il...
# 110245  {'stellar_mocks': {'image_fof': 'http://www.il...
# 110246  {'stellar_mocks': {'image_fof': 'http://www.il...
# 110247  {'stellar_mocks': {'image_fof': 'http://www.il...
# 110248  {'stellar_mocks': {'image_fof': 'http://www.il...
# 110249  {'stellar_mocks': {'image_fof': 'http://www.il...
# 110250  {'stellar_mocks': {'image_fof': 'http://www.il...
# 110251  {'stellar_mocks': {'image_fof': 'http://www.il...
# 110252  {'stellar_mocks': {'image_fof': 'http://www.il...
# 110253  {'stellar_mocks': {'image_fof': 'http://www.il...
# 110254  {'stellar_mocks': {'image_fof': 'http://www.il...
# 110255  {'stellar_mocks': {'image_fof': 'http://www.il...
#
#                                                     trees      vel_x  \
# 0       {'lhalotree_mpb': 'http://www.illustris-projec...   157.3450
# 1       {'lhalotree_mpb': 'http://www.illustris-projec...   276.8820
# 2       {'lhalotree_mpb': 'http://www.illustris-projec...   123.1300
# 3       {'lhalotree_mpb': 'http://www.illustris-projec...   298.8370
# 4       {'lhalotree_mpb': 'http://www.illustris-projec...  -656.7020
# 5       {'lhalotree_mpb': 'http://www.illustris-projec...  -172.7180
# 6       {'lhalotree_mpb': 'http://www.illustris-projec...   654.0550
# 7       {'lhalotree_mpb': 'http://www.illustris-projec...   173.8900
# 8       {'lhalotree_mpb': 'http://www.illustris-projec...  -241.0960
# 9       {'lhalotree_mpb': 'http://www.illustris-projec...   136.3330
# 10      {'lhalotree_mpb': 'http://www.illustris-projec...   245.6040
# 11      {'lhalotree_mpb': 'http://www.illustris-projec...  -541.2630
# 12      {'lhalotree_mpb': 'http://www.illustris-projec...    25.2801
# 13      {'lhalotree_mpb': 'http://www.illustris-projec...    77.8400
# 14      {'lhalotree_mpb': 'http://www.illustris-projec... -1208.7000
# 15      {'lhalotree_mpb': 'http://www.illustris-projec...   -87.8085
# 16      {'lhalotree_mpb': 'http://www.illustris-projec...   816.9030
# 17      {'lhalotree_mpb': 'http://www.illustris-projec...  -331.8870
# 18      {'lhalotree_mpb': 'http://www.illustris-projec...   275.0660
# 19      {'lhalotree_mpb': 'http://www.illustris-projec...  -515.8400
# 20      {'lhalotree_mpb': 'http://www.illustris-projec...   238.0230
# 21      {'lhalotree_mpb': 'http://www.illustris-projec...  -148.0020
# 22      {'lhalotree_mpb': 'http://www.illustris-projec...   583.9650
# 23      {'lhalotree_mpb': 'http://www.illustris-projec...  -161.8270
# 24      {'lhalotree_mpb': 'http://www.illustris-projec...   746.3850
# 25      {'lhalotree_mpb': 'http://www.illustris-projec...   329.5140
# 26      {'lhalotree_mpb': 'http://www.illustris-projec...   266.0200
# 27      {'lhalotree_mpb': 'http://www.illustris-projec...   222.1320
# 28      {'lhalotree_mpb': 'http://www.illustris-projec...    62.9793
# 29      {'lhalotree_mpb': 'http://www.illustris-projec...   243.0980
# ...                                                   ...        ...
# 110226  {'lhalotree_mpb': 'http://www.illustris-projec...  -413.9720
# 110227  {'lhalotree_mpb': 'http://www.illustris-projec...   -31.3342
# 110228  {'lhalotree_mpb': 'http://www.illustris-projec...    84.3719
# 110229  {'lhalotree_mpb': 'http://www.illustris-projec...  -114.8900
# 110230  {'lhalotree_mpb': 'http://www.illustris-projec...  -139.8690
# 110231  {'lhalotree_mpb': 'http://www.illustris-projec...   -27.0856
# 110232  {'lhalotree_mpb': 'http://www.illustris-projec...   127.6740
# 110233  {'lhalotree_mpb': 'http://www.illustris-projec...   188.0850
# 110234  {'lhalotree_mpb': 'http://www.illustris-projec...    79.7476
#  'grnr' 'halfmassrad' 'halfmassrad_bhs' 'halfmassrad_dm' 'halfmassrad_gas'
#  'halfmassrad_stars' 'id' 'len' 'len_bhs' 'len_dm' 'len_gas' 'len_stars'
#  'mass' 'mass_bhs' 'mass_dm' 'mass_gas' 'mass_log_msun' 'mass_stars'
#  'massinhalfrad' 'massinhalfrad_bhs' 'massinhalfrad_dm' 'massinhalfrad_gas'
#  'massinhalfrad_stars' 'massinmaxrad' 'massinmaxrad_bhs' 'massinmaxrad_dm'
#  'massinmaxrad_gas' 'massinmaxrad_stars' 'massinrad' 'massinrad_bhs'
#  'massinrad_dm' 'massinrad_gas' 'massinrad_stars' 'meta' 'parent' 'pos_x'
#  'pos_y' 'pos_z' 'primary_flag' 'prog_sfid' 'prog_snap' 'related' 'sfr'
#  'sfrinhalfrad' 'sfrinmaxrad' 'sfrinrad' 'snap' 'spin_x' 'spin_y' 'spin_z'
#  'starmetallicity' 'starmetallicityhalfrad' 'starmetallicitymaxrad'
#  'stellarphotometrics_b' 'stellarphotometrics_g' 'stellarphotometrics_i'
#  'stellarphotometrics_k' 'stellarphotometrics_r' 'stellarphotometrics_u'
#  'stellarphotometrics_v' 'stellarphotometrics_z'
#  'stellarphotometricsmassinrad' 'stellarphotometricsrad'
#  'supplementary_data' 'trees' 'vel_x' 'vel_y' 'vel_z' 'veldisp' 'vmax'
#  'vmaxrad' 'windmass']

# %% [markdown]
# ## Retrieve data for galaxies that were classified in Galaxy Zoo II from SciServer
# **Notes**:
# The SDSS database lists numerous measurements and derived estimates of the **apparent** magnitude for many galaxies in its dataset. Here the magnitude computed within the **petrosian** radius in each of the SDSS bands (u,g,r,i,z) is used.
#
# Apparent magnitudes are converted to an **absolute** magnitude using the function `fCosmoAbsMag` provided by the SDSS database server. Default values are used for the cosmological description which correspoond with WMAP-5 values. In contrast, the Illustris simulation framework assumes the WMAP-9 values for its cosmological simulation. Since the selected galaxies all have 0.04 < z < 0.06 and the zero-redshift slice of the Illustris simulation was used, this discrepancy should not be problematic.
#
# Vote fraction "probabilities" derived from Galaxy Zoo classifications are also extracted for all galaxies.

# %% [markdown]
# ### Form a query that assembles data from various tables and views using database joins.

# %%
sdssDataBaseQuery = """SELECT spec.z, spec.zErr, spec.zWarning, 
spec.petroMag_u, spec.petroMag_g, spec.petroMag_r, spec.petroMag_i, spec.petroMag_z,   
dbo.fCosmoAbsMag(spec.petroMag_u,spec.z,DEFAULT,DEFAULT,DEFAULT,DEFAULT,DEFAULT) as absPetroMag_u,
dbo.fCosmoAbsMag(spec.petroMag_g,spec.z,DEFAULT,DEFAULT,DEFAULT,DEFAULT,DEFAULT) as absPetroMag_g,
dbo.fCosmoAbsMag(spec.petroMag_r,spec.z,DEFAULT,DEFAULT,DEFAULT,DEFAULT,DEFAULT) as absPetroMag_r,
dbo.fCosmoAbsMag(spec.petroMag_i,spec.z,DEFAULT,DEFAULT,DEFAULT,DEFAULT,DEFAULT) as absPetroMag_i,
dbo.fCosmoAbsMag(spec.petroMag_z,spec.z,DEFAULT,DEFAULT,DEFAULT,DEFAULT,DEFAULT) as absPetroMag_z,
zooSpecExtra.* FROM 
(
SELECT 
zoo.objid, zoo.dr7objid, zoo.ra, zoo.dec, zoo.rastring, zoo.decstring, zoo.nvote, 
zoo.p_el, zoo.p_cw, zoo.p_acw, zoo.p_edge, zoo.p_dk, zoo.p_mg, zoo.p_cs, zoo.p_el_debiased, zoo.p_cs_debiased,
spiral, zoo.elliptical, zoo.uncertain, specExtra.*
FROM zooSpec AS zoo 
LEFT JOIN 
galSpecExtra AS specExtra 
ON (specExtra.specObjID = zoo.specobjid) 
) 
AS zooSpecExtra 
LEFT JOIN
SpecPhoto AS spec 
ON 
(spec.specObjID = zooSpecExtra.specobjid) 
WHERE 
(spec.z > 0.04 AND spec.z < 0.06)
"""

# %% [markdown]
# ### Execute the query using the SciServer CasJobs API
# Note that **Data release 8** (`dr8`) must be specified as the query context, since extiates of stellar mass and star formation rate (retrieved from the `specExtra` table) do not exist for later releases.
#
# The SciServer CasJobs API returns query results as a `pandas.DataFrame`, so no additional data manipulation is required once the API returns.

# %%
sdssDataBaseQueryResult = None
if saveGalaxyZooSDSSDataFrame :
    galaxyZooSDSSDataFrame = CasJobs.executeQuery(sdssDataBaseQuery, "dr8", token=sciServerAuthToken)
    galaxyZooSDSSDataFrame.to_pickle(galaxyZooSDSSDataFramePath)
else :
    pickleDataFile = open(galaxyZooSDSSDataFramePath, mode='rb')
    galaxyZooSDSSDataFrame = pickle.load(pickleDataFile) 
    pickleDataFile.close()
    
if verbose :
    display(galaxyZooSDSSDataFrame)
    prettyPrinter.pprint(galaxyZooSDSSDataFrame.columns.values)
# Out:
#               z      zErr  zWarning  petroMag_u  petroMag_g  petroMag_r  \
# 0      0.047411  0.000012         0    18.54880    16.85961    16.03727
# 1      0.044529  0.000010         0    17.52230    16.12248    15.41560
# 2      0.055087  0.000016         0    18.07451    16.35515    15.49084
# 3      0.050788  0.000006         0    18.60359    17.40190    16.99499
# 4      0.054887  0.000014         0    18.22514    16.39491    15.48788
# 5      0.054096  0.000017         0    19.18540    17.50917    16.73115
# 6      0.059259  0.000012         0    18.44806    16.46276    15.58985
# 7      0.048742  0.000013         0    17.26015    15.53435    14.91835
# 8      0.054950  0.000013         0    18.10780    16.23346    15.34903
# 9      0.055170  0.000019         0    18.05796    16.62740    15.68419
# 10     0.054414  0.000015         0    18.82888    17.10785    16.35954
# 11     0.040323  0.000013         0    17.47781    16.13396    15.37702
# 12     0.059557  0.000014         0    18.57598    16.66094    15.81387
# 13     0.054328  0.000018         0    19.29127    17.50375    16.54337
# 14     0.054918  0.000018         0    17.91003    16.53431    15.76773
# 15     0.056228  0.000012         0    17.53915    16.15770    15.53533
# 16     0.052557  0.000015         0    17.75571    16.33202    15.56517
# 17     0.042396  0.000011         0    18.23865    16.44267    15.55467
# 18     0.045453  0.000011         0    17.26130    16.01798    15.39559
# 19     0.051979  0.000019         0    19.40656    17.62955    16.77055
# 20     0.050435  0.000008         0    18.52817    16.90428    16.19980
# 21     0.048418  0.000011         0    18.62296    16.85585    16.00413
# 22     0.047623  0.000011         0    18.30346    17.49358    16.94090
# 23     0.056128  0.000012         0    18.48609    17.22427    16.58755
# 24     0.046049  0.000025         0    19.93461    17.88877    17.01089
# 25     0.055412  0.000006         0    17.89614    16.86823    16.53820
# 26     0.047418  0.000009         0    19.55154    17.60447    16.89200
# 27     0.051250  0.000009         0    19.02860    17.47408    16.67497
# 28     0.055302  0.000018         0    19.19915    17.78454    16.99959
# 20            ...               -11.336670       -10.621870
# 21            ...               -12.200540       -11.379030
# 22            ...                -9.993506        -9.666298
# 23            ...               -10.153750        -9.889631
# 24            ...               -11.146600       -10.675210
# 25            ...                -9.564713        -9.317068
# 26            ...               -10.527780       -10.203890
# 27            ...               -11.693260       -10.892050
# 28            ...               -10.498600       -10.081480
# 29            ...               -12.195780       -11.233330
# ...           ...                      ...              ...
# 38786         ...                -9.862354        -9.607865
# 38787         ...               -12.084480       -11.221430
# 38788         ...               -12.063330       -11.233130
# 38789         ...               -12.481170       -11.631310
# 38790         ...               -11.955750       -11.144210
# 38791         ...                -9.996440        -9.653090
# 38792         ...                -9.669809        -9.485510
# 38793         ...               -10.248100        -9.916105
# 38794         ...                -9.862745        -9.598870
# 38795         ...               -10.207340       -10.004790
# 38796         ...               -12.120480       -11.250450
# 38797         ...                -9.536518        -9.243670
# 38798         ...                -9.818306        -9.519430
# 38799         ...               -10.277840        -9.827604
# 38800         ...               -12.132140       -11.340150
# 38801         ...               -11.926670       -11.218260
# 38802         ...               -10.452550       -10.185280
# 38803         ...               -10.269330        -9.925510
# 38804         ...               -10.148130        -9.924669
# 38805         ...               -12.534780       -11.678740
# 38806         ...               -10.273500        -9.909142
# 38807         ...               -12.238070       -11.384130
# 38808         ...               -11.569720       -11.153910
# 38809         ...               -10.238890        -9.908580
# 38810         ...               -10.100660        -9.846903
# 38811         ...                -9.411125        -9.290103
# 38812         ...               -12.469440       -11.569010
# 38813         ...               -11.183440       -10.551030
# 38814         ...               -10.476630       -10.215710
# 38815         ...                -9.965819        -9.693143
#
#        specsfr_tot_p97p5  specsfr_tot_entropy specsfr_fib_p2p5  \
# 0             -10.932760            -6.278834       -14.620370
# 1              -9.731944            -4.224891       -10.286080
# 2             -10.742500            -6.322618       -14.495450
# 3              -9.338000            -4.310218       -10.148950
# 4             -11.066670            -6.224016       -14.650000
# 5             -10.208330            -6.285340       -14.200000
# 6             -10.758330            -6.382539       -14.715620
# 7              -9.768749            -4.781360       -12.504550
# 8             -10.626090            -6.268757       -14.519230
# 9              -9.855769            -5.624289       -12.876920
# 10            -10.092590            -5.951275       -13.787500
# 11             -9.964999            -5.812481       -14.197220
# 12            -10.816670            -6.341700       -14.678570
# 13            -10.519230            -6.208690       -14.436110
# 14            -10.581080            -6.254709       -14.307140
# 15             -9.646428            -4.805972       -13.656250
# 16            -10.102170            -5.650566       -11.942860
# 17            -10.920590            -6.267006       -14.584090
# 18             -9.632857            -4.275627       -10.338420
# 19            -10.425000            -6.292693       -14.334090
# 20             -9.961290            -6.347132       -14.290000
# 21            -10.756060            -6.305775       -14.609520
# 22             -9.343590            -4.829063       -10.753450
# 23             -9.561110            -4.378767       -10.465320
# 24            -10.111290            -5.327530       -11.656560
# 25             -8.937037            -4.358260       -10.127910
# 26             -9.752941            -4.749548       -10.607460
# 27            -10.261360            -6.385131       -14.486840
# 28             -9.558928            -5.078928       -12.025000
# 29            -10.495240            -6.439058       -14.560000
# ...                  ...                  ...              ...
# 38786          -9.226923            -4.244385        -9.956250
# 29          -13.341030       -11.940480       -11.013070        -10.241300
# ...                ...              ...              ...               ...
# 38786        -9.810428        -9.663582        -9.521615         -9.402631
# 38787       -13.410000       -12.097420       -11.318870        -10.780880
# 38788       -13.304050       -12.028380       -11.215840        -10.664810
# 38789       -13.548150       -12.349560       -11.517330        -10.871430
# 38790       -13.188300       -11.881550       -11.104900        -10.487500
# 38791       -10.486950       -10.293720       -10.083660         -9.893182
# 38792        -9.347746        -9.206451        -9.082449         -8.970073
# 38793       -10.258680       -10.092060        -9.924794         -9.753932
# 38794       -10.152720        -9.888269        -9.601755         -9.286458
# 38795        -9.908571        -9.728217        -9.548062         -9.356165
# 38796       -13.430680       -12.123530       -11.242780        -10.600000
# 38797        -9.796474        -9.662997        -9.543240         -9.427155
# 38798       -10.086920        -9.912781        -9.725836         -9.549999
# 38799       -10.415840       -10.011240        -9.606123         -9.309999
# 38800       -13.407810       -12.097850       -11.291450        -10.691070
# 38801       -13.171880       -11.918300       -11.173680        -10.563640
# 38802       -10.416670       -10.186350        -9.955670         -9.737000
# 38803       -12.846050       -11.499550       -10.886050        -10.422920
# 38804       -10.016980        -9.809590        -9.589559         -9.361250
# 38805       -13.685580       -12.600480       -11.721760        -11.050000
# 38806       -10.887790       -10.529640       -10.152960         -9.741936
# 38807       -13.440570       -12.273560       -11.430460        -10.811540
# 38808       -11.444650       -11.278070       -11.068580        -10.852220
# 38809       -10.956930       -10.630180       -10.233960         -9.824286
# 38810       -10.021050        -9.882153        -9.750753         -9.619159
# 38811        -9.137017        -9.003444        -8.882647         -8.771642
# 38812       -13.506670       -12.291920       -11.459440        -10.835000
# 38813       -11.594550       -10.788780       -10.248720         -9.667999
# 38814        -9.824047        -9.653990        -9.481749         -9.313067
# 38815        -9.902272        -9.762660        -9.638041         -9.519835
#
#       specsfr_fib_entropy
# 0               -6.340616
# 1               -4.025777
# 2               -6.299952
# 3               -3.451127
# 4               -6.244517
# 5               -6.245118
# 6               -6.324888
# 7               -5.362657
# 8               -6.431592
# 9               -5.729641
# 10              -5.862950
# 11              -6.158669
# 12              -6.261921
# 13              -6.230114
# 14              -6.313980
# 15              -5.876305
# 16              -5.422914
# 17              -6.308356
# 18              -4.168850
# 19              -6.241450
# 20              -6.366565
# 21              -6.280106
# 22              -4.172001
# 23              -4.366937
# 24              -4.906076
# 25              -3.485441
# 26              -4.159210
# 27              -6.339750
# 28              -5.374435
# 29              -6.465847
# ...                   ...
# 38786           -3.556280
# 38787           -6.240376
# 38788           -6.257065
# 38789           -6.282866
# 38790           -6.285745
# 38791           -4.043523
# 38792           -3.442105
# 38793           -3.780402
# 38794           -4.518543
# 38795           -3.917648
# 38796           -6.369843
# 38797           -3.429985
# 38798           -3.906137
# 38799           -5.026782
# 38800           -6.283520
# 38801           -6.267459
# 38802           -4.234317
# 38803           -6.155665
# 38804           -4.166358
# 38805           -6.245571
# 38806           -5.089051
# 38807           -6.236207
# 38808           -3.909631
# 38809           -4.822592
# 38810           -3.480579
# 38811           -3.377401
# 38812           -6.270468
# 38813           -5.909775
# 38814           -3.822934
# 38815           -3.457820
#
# [38816 rows x 286 columns]
# array(['z', 'zErr', 'zWarning', 'petroMag_u', 'petroMag_g', 'petroMag_r',
#        'petroMag_i', 'petroMag_z', 'absPetroMag_u', 'absPetroMag_g',
#        'absPetroMag_r', 'absPetroMag_i', 'absPetroMag_z', 'dec',
#        'decstring', 'dr7objid', 'dr8objid', 'ra', 'rastring', 'sample',
#        't01_smooth_or_features_a01_smooth_count',
#        't01_smooth_or_features_a01_smooth_debiased',
#        't01_smooth_or_features_a01_smooth_flag',
#        't01_smooth_or_features_a01_smooth_fraction',
#        't01_smooth_or_features_a01_smooth_weight',
#        't01_smooth_or_features_a01_smooth_weighted_fraction',
#        't01_smooth_or_features_a02_features_or_disk_count',
#        't01_smooth_or_features_a02_features_or_disk_debiased',
#        't01_smooth_or_features_a02_features_or_disk_flag',
#        't01_smooth_or_features_a02_features_or_disk_fraction',
#        't01_smooth_or_features_a02_features_or_disk_weight',
#        't01_smooth_or_features_a02_features_or_disk_weighted_fraction',
#        't01_smooth_or_features_a03_star_or_artifact_count',
#        't01_smooth_or_features_a03_star_or_artifact_debiased',
#        't01_smooth_or_features_a03_star_or_artifact_flag',
#        't01_smooth_or_features_a03_star_or_artifact_fraction',
#        't01_smooth_or_features_a03_star_or_artifact_weight',
#        't01_smooth_or_features_a03_star_or_artifact_weighted_fraction',
#        't02_edgeon_a04_yes_count', 't02_edgeon_a04_yes_debiased',
#        't02_edgeon_a04_yes_flag', 't02_edgeon_a04_yes_fraction',
#        't02_edgeon_a04_yes_weight', 't02_edgeon_a04_yes_weighted_fraction',
#        't02_edgeon_a05_no_count', 't02_edgeon_a05_no_debiased',
#        't02_edgeon_a05_no_flag', 't02_edgeon_a05_no_fraction',
#        't02_edgeon_a05_no_weight', 't02_edgeon_a05_no_weighted_fraction',
#        't03_bar_a06_bar_count', 't03_bar_a06_bar_debiased',
#        't03_bar_a06_bar_flag', 't03_bar_a06_bar_fraction',
#        't03_bar_a06_bar_weight', 't03_bar_a06_bar_weighted_fraction',
#        't03_bar_a07_no_bar_count', 't03_bar_a07_no_bar_debiased',
#        't03_bar_a07_no_bar_flag', 't03_bar_a07_no_bar_fraction',
#        't03_bar_a07_no_bar_weight', 't03_bar_a07_no_bar_weighted_fraction',
#        't04_spiral_a08_spiral_count', 't04_spiral_a08_spiral_debiased',
#        't04_spiral_a08_spiral_flag', 't04_spiral_a08_spiral_fraction',
#        't04_spiral_a08_spiral_weight',
#        't04_spiral_a08_spiral_weighted_fraction',
#        't04_spiral_a09_no_spiral_count',
#        't04_spiral_a09_no_spiral_debiased',
#        't04_spiral_a09_no_spiral_flag',
#        't04_spiral_a09_no_spiral_fraction',
#        't04_spiral_a09_no_spiral_weight',
#        't04_spiral_a09_no_spiral_weighted_fraction',
#        't05_bulge_prominence_a10_no_bulge_count',
#        't05_bulge_prominence_a10_no_bulge_debiased',
#        't05_bulge_prominence_a10_no_bulge_flag',
#        't05_bulge_prominence_a10_no_bulge_fraction',
#        't05_bulge_prominence_a10_no_bulge_weight',
#        't05_bulge_prominence_a10_no_bulge_weighted_fraction',
#        't05_bulge_prominence_a11_just_noticeable_count',
#        't05_bulge_prominence_a11_just_noticeable_debiased',
#        't05_bulge_prominence_a11_just_noticeable_flag',
#        't05_bulge_prominence_a11_just_noticeable_fraction',
#        't05_bulge_prominence_a11_just_noticeable_weight',
#        't05_bulge_prominence_a11_just_noticeable_weighted_fraction',
#        't05_bulge_prominence_a12_obvious_count',
#        't05_bulge_prominence_a12_obvious_debiased',
#        't05_bulge_prominence_a12_obvious_flag',
#        't05_bulge_prominence_a12_obvious_fraction',
#        't05_bulge_prominence_a12_obvious_weight',
#        't05_bulge_prominence_a12_obvious_weighted_fraction',
#        't05_bulge_prominence_a13_dominant_count',
#        't05_bulge_prominence_a13_dominant_debiased',
#        't05_bulge_prominence_a13_dominant_flag',
#        't05_bulge_prominence_a13_dominant_fraction',
#        't05_bulge_prominence_a13_dominant_weight',
#        't05_bulge_prominence_a13_dominant_weighted_fraction',
#        't06_odd_a14_yes_count', 't06_odd_a14_yes_debiased',
#        't06_odd_a14_yes_flag', 't06_odd_a14_yes_fraction',
#        't06_odd_a14_yes_weight', 't06_odd_a14_yes_weighted_fraction',
#        't06_odd_a15_no_count', 't06_odd_a15_no_debiased',
#        't06_odd_a15_no_flag', 't06_odd_a15_no_fraction',
#        't06_odd_a15_no_weight', 't06_odd_a15_no_weighted_fraction',
#        't07_rounded_a16_completely_round_count',
#        't07_rounded_a16_completely_round_debiased',
#        't07_rounded_a16_completely_round_flag',
#        't07_rounded_a16_completely_round_fraction',
#        't07_rounded_a16_completely_round_weight',
#        't07_rounded_a16_completely_round_weighted_fraction',
#        't07_rounded_a17_in_between_count',
#        't07_rounded_a17_in_between_debiased',
#        't07_rounded_a17_in_between_flag',
#        't07_rounded_a17_in_between_fraction',
#        't07_rounded_a17_in_between_weight',
#        't07_rounded_a17_in_between_weighted_fraction',
#        't07_rounded_a18_cigar_shaped_count',
#        't07_rounded_a18_cigar_shaped_debiased',
#        't07_rounded_a18_cigar_shaped_flag',
#        't07_rounded_a18_cigar_shaped_fraction',
#        't07_rounded_a18_cigar_shaped_weight',
#        't07_rounded_a18_cigar_shaped_weighted_fraction',
#        't08_odd_feature_a19_ring_count',
#        't08_odd_feature_a19_ring_debiased',
#        't08_odd_feature_a19_ring_flag',
#        't08_odd_feature_a19_ring_fraction',
#        't08_odd_feature_a19_ring_weight',
#        't08_odd_feature_a19_ring_weighted_fraction',
#        't08_odd_feature_a20_lens_or_arc_count',
#        't08_odd_feature_a20_lens_or_arc_debiased',
#        't08_odd_feature_a20_lens_or_arc_flag',
#        't08_odd_feature_a20_lens_or_arc_fraction',
#        't08_odd_feature_a20_lens_or_arc_weight',
#        't08_odd_feature_a20_lens_or_arc_weighted_fraction',
#        't08_odd_feature_a21_disturbed_count',
#        't08_odd_feature_a21_disturbed_debiased',
#        't08_odd_feature_a21_disturbed_flag',
#        't08_odd_feature_a21_disturbed_fraction',
#        't08_odd_feature_a21_disturbed_weight',
#        't08_odd_feature_a21_disturbed_weighted_fraction',
#        't08_odd_feature_a22_irregular_count',
#        't08_odd_feature_a22_irregular_debiased',
#        't08_odd_feature_a22_irregular_flag',
#        't08_odd_feature_a22_irregular_fraction',
#        't08_odd_feature_a22_irregular_weight',
#        't08_odd_feature_a22_irregular_weighted_fraction',
#        't08_odd_feature_a23_other_count',
#        't08_odd_feature_a23_other_debiased',
#        't08_odd_feature_a23_other_flag',
#        't08_odd_feature_a23_other_fraction',
#        't08_odd_feature_a23_other_weight',
#        't08_odd_feature_a23_other_weighted_fraction',
#        't08_odd_feature_a24_merger_count',
#        't08_odd_feature_a24_merger_debiased',
#        't08_odd_feature_a24_merger_flag',
#        't08_odd_feature_a24_merger_fraction',
#        't08_odd_feature_a24_merger_weight',
#        't08_odd_feature_a24_merger_weighted_fraction',
#        't08_odd_feature_a38_dust_lane_count',
#        't08_odd_feature_a38_dust_lane_debiased',
#        't08_odd_feature_a38_dust_lane_flag',
#        't08_odd_feature_a38_dust_lane_fraction',
#        't08_odd_feature_a38_dust_lane_weight',
#        't08_odd_feature_a38_dust_lane_weighted_fraction',
#        't09_bulge_shape_a25_rounded_count',
#        't09_bulge_shape_a25_rounded_debiased',
#        't09_bulge_shape_a25_rounded_flag',
#        't09_bulge_shape_a25_rounded_fraction',
#        't09_bulge_shape_a25_rounded_weight',
#        't09_bulge_shape_a25_rounded_weighted_fraction',
#        't09_bulge_shape_a26_boxy_count',
#        't09_bulge_shape_a26_boxy_debiased',
#        't09_bulge_shape_a26_boxy_flag',
#        't09_bulge_shape_a26_boxy_fraction',
#        't09_bulge_shape_a26_boxy_weight',
#        't09_bulge_shape_a26_boxy_weighted_fraction',
#        't09_bulge_shape_a27_no_bulge_count',
#        't09_bulge_shape_a27_no_bulge_debiased',
#        't09_bulge_shape_a27_no_bulge_flag',
#        't09_bulge_shape_a27_no_bulge_fraction',
#        't09_bulge_shape_a27_no_bulge_weight',
#        't09_bulge_shape_a27_no_bulge_weighted_fraction',
#        't10_arms_winding_a28_tight_count',
#        't10_arms_winding_a28_tight_debiased',
#        't10_arms_winding_a28_tight_flag',
#        't10_arms_winding_a28_tight_fraction',
#        't10_arms_winding_a28_tight_weight',
#        't10_arms_winding_a28_tight_weighted_fraction',
#        't10_arms_winding_a29_medium_count',
#        't10_arms_winding_a29_medium_debiased',
#        't10_arms_winding_a29_medium_flag',
#        't10_arms_winding_a29_medium_fraction',
#        't10_arms_winding_a29_medium_weight',
#        't10_arms_winding_a29_medium_weighted_fraction',
#        't10_arms_winding_a30_loose_count',
#        't10_arms_winding_a30_loose_debiased',
#        't10_arms_winding_a30_loose_flag',
#        't10_arms_winding_a30_loose_fraction',
#        't10_arms_winding_a30_loose_weight',
#        't10_arms_winding_a30_loose_weighted_fraction',
#        't11_arms_number_a31_1_count', 't11_arms_number_a31_1_debiased',
#        't11_arms_number_a31_1_flag', 't11_arms_number_a31_1_fraction',
#        't11_arms_number_a31_1_weight',
#        't11_arms_number_a31_1_weighted_fraction',
#        't11_arms_number_a32_2_count', 't11_arms_number_a32_2_debiased',
#        't11_arms_number_a32_2_flag', 't11_arms_number_a32_2_fraction',
#        't11_arms_number_a32_2_weight',
#        't11_arms_number_a32_2_weighted_fraction',
#        't11_arms_number_a33_3_count', 't11_arms_number_a33_3_debiased',
#        't11_arms_number_a33_3_flag', 't11_arms_number_a33_3_fraction',
#        't11_arms_number_a33_3_weight',
#        't11_arms_number_a33_3_weighted_fraction',
#        't11_arms_number_a34_4_count', 't11_arms_number_a34_4_debiased',
#        't11_arms_number_a34_4_flag', 't11_arms_number_a34_4_fraction',
#        't11_arms_number_a34_4_weight',
#        't11_arms_number_a34_4_weighted_fraction',
#        't11_arms_number_a36_more_than_4_count',
#        't11_arms_number_a36_more_than_4_debiased',
#        't11_arms_number_a36_more_than_4_flag',
#        't11_arms_number_a36_more_than_4_fraction',
#        't11_arms_number_a36_more_than_4_weight',
#        't11_arms_number_a36_more_than_4_weighted_fraction',
#        't11_arms_number_a37_cant_tell_count',
#        't11_arms_number_a37_cant_tell_debiased',
#        't11_arms_number_a37_cant_tell_flag',
#        't11_arms_number_a37_cant_tell_fraction',
#        't11_arms_number_a37_cant_tell_weight',
#        't11_arms_number_a37_cant_tell_weighted_fraction',
#        'total_classifications', 'total_votes', 'specObjID', 'bptclass',
#        'oh_p2p5', 'oh_p16', 'oh_p50', 'oh_p84', 'oh_p97p5', 'oh_entropy',
#        'lgm_tot_p2p5', 'lgm_tot_p16', 'lgm_tot_p50', 'lgm_tot_p84',
#        'lgm_tot_p97p5', 'lgm_fib_p2p5', 'lgm_fib_p16', 'lgm_fib_p50',
#        'lgm_fib_p84', 'lgm_fib_p97p5', 'sfr_tot_p2p5', 'sfr_tot_p16',
#        'sfr_tot_p50', 'sfr_tot_p84', 'sfr_tot_p97p5', 'sfr_tot_entropy',
#        'sfr_fib_p2p5', 'sfr_fib_p16', 'sfr_fib_p50', 'sfr_fib_p84',
#        'sfr_fib_p97p5', 'sfr_fib_entropy', 'specsfr_tot_p2p5',
#        'specsfr_tot_p16', 'specsfr_tot_p50', 'specsfr_tot_p84',
#        'specsfr_tot_p97p5', 'specsfr_tot_entropy', 'specsfr_fib_p2p5',
#        'specsfr_fib_p16', 'specsfr_fib_p50', 'specsfr_fib_p84',
#        'specsfr_fib_p97p5', 'specsfr_fib_entropy'], dtype=object)

# %% [markdown]
# ## Manipulate the Illustris galaxy data as appropriate and compare with SDSS properties
# ### The distribution of stellar masses
# Plot distributions of stellar masses for the full dataset, the subset of galaxies that are paused and various options for subsets to unpause.

# %%
hubbleConstant = 0.74

# %%
gc.collect()
illustrisStellarMassesFrame['logstellarmasses'] = np.log10(10**10*(illustrisStellarMassesFrame["mass_stars"]/hubbleConstant))
pausedIllustrisStellarMassesFrame = illustrisStellarMassesFrame[illustrisStellarMassesFrame['state'] == 'paused']

thresholds = (10.7, 10.8, 10.9, 11, 11.1, 11.2, 11.3, 11.4, 11.5)

thresholdedPausedIllustrisStellarMasses = { threshold : pausedIllustrisStellarMassesFrame[pausedIllustrisStellarMassesFrame['logstellarmasses'] > threshold]['logstellarmasses'] for threshold in thresholds}

unpauseSubsetFigure = plt.figure(figsize=(10,5))

unpauseSubsetAxes = pausedIllustrisStellarMassesFrame['logstellarmasses'].plot.hist(zorder=2, bins=50, histtype='step', logy=True, fill=False, color='k', range=(10, 12.5), label='All Paused ({})'.format(len(pausedIllustrisStellarMassesFrame.index)))
illustrisStellarMassesFrame['logstellarmasses'].plot.hist(zorder=1, bins=50, histtype='step', ls='dotted', logy=True, fill=False, color='k', range=(10, 12.5), label='All ({})'.format(len(illustrisStellarMassesFrame.index)))

cmap = matplotlib.cm.get_cmap('viridis')

for index, threshold in enumerate(sorted(thresholdedPausedIllustrisStellarMasses)) :
    print(threshold, len(thresholdedPausedIllustrisStellarMasses[threshold]))
    plotColor=cmap(index/len(thresholdedPausedIllustrisStellarMasses))
    thresholdedPausedIllustrisStellarMasses[threshold].plot.hist(zorder=1, fc=plotColor, ec=plotColor, bins=50, histtype='step', logy=True, fill=False, hatch='//', ax=unpauseSubsetAxes, range=(10, 12.5), label=r'Paused: $M_{}/M_{} > 10^{}{}{}$ ({})'.format(r'{\star}', r'{\odot}','{', threshold, '}', len(thresholdedPausedIllustrisStellarMasses[threshold])))

lines, labels = unpauseSubsetAxes.get_legend_handles_labels()
legendOrder=[1, 0]
legendOrder.extend([position for position in range(2, len(lines))])
print(legendOrder)

unpauseSubsetAxes.legend([lines[position] for position in legendOrder], [labels[position] for position in legendOrder], loc='best', fontsize='small', ncol=3)
unpauseSubsetAxes.set_ylim(10, 1e5)

plt.xlabel(r'$\log(M_{\star})[M_{\odot}]$', size=15)
# Out:
# 10.7 20370
# 10.8 14940
# 10.9 10710
# 11 7080
# 11.1 4995
# 11.2 3630
# 11.3 2775
# 11.4 2400
# 11.5 1875
# [1, 0, 2, 3, 4, 5, 6, 7, 8, 9, 10]

# %% [markdown]
# ### The distributions of absolute magnitudes in the SDSS (u, g, r, i, z) bands

# %%
magLimits = {'u':22,
             'g':22.2,
             'r': 17.77,
             'i':21.3,
             'z':20.5}

illustrisAbsMagFigure = plt.figure(figsize=(15, 15))
illustrisAbsMagFigure.suptitle('Illustris Absolute Magnitudes', size=12)

for index, value in enumerate(['u','g','r','i','z']) :
    subplotAxis = plt.subplot(3, 2, index+1)
    fullIllustrisWebServiceDataFrame['stellarphotometrics_' + value].plot.hist(ax=subplotAxis, normed=True, bins=50, histtype='step', logy=True, fill=False, color='r')
    galaxyZooSDSSDataFrame[np.logical_and(galaxyZooSDSSDataFrame['absPetroMag_r'] > -9000, np.logical_and(galaxyZooSDSSDataFrame['petroMag_' + value] < magLimits[value], galaxyZooSDSSDataFrame['lgm_tot_p97p5'] > 10))][['absPetroMag_' + value]].plot.hist(normed=True, ax=subplotAxis, bins=50, histtype='step', logy=True, fill=False, label='SDSS ' + value.upper(), color='b')
    lines, labels = subplotAxis.get_legend_handles_labels()
    labels = ['Illustris ' + str(value.upper()), 'SDSS ' + str(value.upper())]
    subplotAxis.legend(lines[:2], labels[:2], loc='best')
    plt.xlabel("Absolute magnitude")
